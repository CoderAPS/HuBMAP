# %% [markdown]
# <a href="https://colab.research.google.com/github/CoderAPS/HuBMAP/blob/main/HuBMAP_load_modules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Check RAM
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime

# %%
# Mount google drive
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# !ls /gdrive/MyDrive/DATA/HuBMAP
# Out:
# annotation_count.csv  polygons.jsonl	     tile_meta.csv
# masks		      sample_submission.csv  train
# masks_4d	      test		     wsi_meta.csv

# %%
# Import libraries
import pandas as pd
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
# !cp /gdrive/MyDrive/python_modules/normalize_he_image.py .

# %%
import normalize_he_image

# %%
image_file_path = '/gdrive/MyDrive/DATA/HuBMAP/train/0006ff2aa7cd.tif'

# %%
normalized,h,e = normalize_he_image.normalize_HnE_stain(image_file_path)

# %%
plt.imshow(normalized)

# %%
h.shape
# Out:
# (512, 512, 3)
