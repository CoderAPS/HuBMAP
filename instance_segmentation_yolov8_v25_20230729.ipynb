# %% [markdown]
# <a href="https://colab.research.google.com/github/CoderAPS/HuBMAP/blob/main/instance_segmentation_yolov8_v25_20230729.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Medical Instance Segmentation with YOLOv8 version 25
# References:<br>
# https://docs.ultralytics.com/usage/cfg/#tasks <br>
# how YOLO v8 works: https://openmmlab.medium.com/dive-into-yolov8-how-does-this-state-of-the-art-model-work-10f18f74bab1 <br>
#
# about COCO dataset and format:<br>
# https://towardsdatascience.com/master-the-coco-dataset-for-semantic-image-segmentation-part-1-of-2-732712631047<br>
#
# training with yolov8:<br>
# https://learnopencv.com/train-yolov8-on-custom-dataset/
#
# Various YOLOv8 models: <br>
# https://docs.ultralytics.com/tasks/segment/#models
#
#
# Train YOLOv8 Instance Segmentation on Your Data<br>
# https://towardsdatascience.com/trian-yolov8-instance-segmentation-on-your-data-6ffa04b2debd
#
# recall vs precision<br>
# https://medium.com/@shrutisaxena0617/precision-vs-recall-386cf9f89488
#
# dialation<br>
# https://www.geeksforgeeks.org/dilated-convolution/
# How to dilate an image using OpenCV?<br>
# https://www.projectpro.io/recipes/what-is-dilation-of-image-dilate-image-opencv
# https://www.geeksforgeeks.org/erosion-dilation-images-using-opencv-python/
# https://www.educative.io/answers/dilation-on-an-image-using-opencv-in-python

# %% [markdown]
# Run 1: <br>
# Split: 0.85 & 0.15, LR0 = 0.005, weight decay = 0.005, batch = 16, droupout = 0.1, patience = 6, epoch = 60 (), image size = 512,pre-train = True, model =  yolov8x-seg.pt,  data = /gdrive/MyDrive/DATA/HuBMAP/dilated_images(coco_85train_dataset4)

# %%
# Mount google drive
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.3 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
# !ls /gdrive/MyDrive/DATA/HuBMAP/
# Out:
# annotation_info.csv    images		      test
# blue_images	       images_info.csv	      test2
# coco_85train_dataset   masks		      test_list.csv
# coco_85train_dataset2  masks_white_bkgrnd     tile_meta.csv
# coco_85train_dataset3  norm_images	      train_list.csv
# coco_85train_dataset4  polygons.jsonl	      val_list.csv
# dilated_images	       red_images	      wsi_meta.csv
# enhanced_images        Results
# gray_images	       sample_submission.csv

# %%
# !pip install colorama
# Out:
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama
# Successfully installed colorama-0.4.6

# %%
# libraries needed to create the create the dataset in COCO format
from itertools import chain
import json
import os
import glob
import shutil
from tqdm.notebook import tqdm
from colorama import Fore
import yaml
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from PIL import Image
import cv2

# use this code to clear output
from IPython import display
from google.colab import files
#display.clear_output()

# %%
dirlist = os.listdir("/gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/")
random_num = np.random.randint(0, len(dirlist))
image = Image.open("/gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/"+ dirlist[random_num])
plt.imshow(image)
plt.show()

# %%
img_arr = np.array(image)
img_arr.shape
# Out:
# (512, 512, 3)

# %%
# install ultralytics version 8.0.131
# !pip install ultralytics==8.0.131
display.clear_output()

# %%
pip show ultralytics
# Out:
# Name: ultralytics
# Version: 8.0.131
# Summary: Ultralytics YOLOv8 for SOTA object detection, multi-object tracking, instance segmentation, pose estimation and image classification.
# Home-page: https://github.com/ultralytics/ultralytics
# Author: Ultralytics
# Author-email: hello@ultralytics.com
# License: AGPL-3.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: matplotlib, opencv-python, pandas, Pillow, psutil, PyYAML, requests, scipy, seaborn, torch, torchvision, tqdm
# Required-by:

# %%
# install pycocotools version 2.0.6
# !pip install pycocotools==2.0.6
display.clear_output()

# %%
pip show pycocotools
# Out:
# Name: pycocotools
# Version: 2.0.6
# Summary: Official APIs for the MS-COCO dataset
# Home-page: https://github.com/ppwwyyxx/cocoapi
# Author:
# Author-email:
# License: FreeBSD
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: matplotlib, numpy
# Required-by:

# %%
from pycocotools import _mask as coco_mask
import ultralytics
from ultralytics import YOLO

# %%
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.131 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (4 CPUs, 25.5 GB RAM, 24.3/166.8 GB disk)

# %%
# !nvidia-smi
# Out:
# Sun Jul 30 02:39:59 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8     9W /  70W |      3MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
def main():
    model = YOLO("yolov8x-seg.pt")
    model.train(
        # Project
        project="HuBMAP",
        name="yolov8x-seg",

        # Random Seed parameters
        deterministic=True,
        seed=43,

        # Data & model parameters
        data="/gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/coco.yaml",
        save=True,
        save_period=5,
        pretrained=True,
        imgsz=512,

        # Training parameters
        epochs=60,
        batch=16,
        workers=8,
        val=True,
        device=0,

        # Optimization parameters
        lr0=0.005,
        cos_lr=True,
        patience=6,
        optimizer="SGD",
        momentum=0.947,
        weight_decay=0.005,
        close_mosaic=3,
        dropout = 0.1
    )

# %%
if __name__ == '__main__':
    main()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8x-seg.pt to yolov8x-seg.pt...
# 100%|██████████| 137M/137M [00:09<00:00, 15.9MB/s]
# New https://pypi.org/project/ultralytics/8.0.145 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.131 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# yolo/engine/trainer: task=segment, mode=train, model=yolov8x-seg.pt, data=/gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/coco.yaml, epochs=60, patience=6, batch=16, imgsz=512, save=True, save_period=5, cache=False, device=0, workers=8, project=HuBMAP, name=yolov8x-seg, exist_ok=False, pretrained=True, optimizer=SGD, verbose=True, seed=43, deterministic=True, single_cls=False, rect=False, cos_lr=True, close_mosaic=3, resume=False, amp=True, fraction=1.0, profile=False, overlap_mask=True, mask_ratio=4, dropout=0.1, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.005, lrf=0.01, momentum=0.947, weight_decay=0.005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=HuBMAP/yolov8x-seg
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100%|██████████| 755k/755k [00:00<00:00, 113MB/s]
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#   8                  -1  3   6969600  ultralytics.nn.modules.block.C2f             [640, 640, 3, True]
#   9                  -1  1   1025920  ultralytics.nn.modules.block.SPPF            [640, 640, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1948800  ultralytics.nn.modules.block.C2f             [960, 320, 3]
#  16                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   7174400  ultralytics.nn.modules.block.C2f             [960, 640, 3]
#  19                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  22        [15, 18, 21]  1  12319097  ultralytics.nn.modules.head.Segment          [3, 32, 320, [320, 640, 640]]
# YOLOv8x-seg summary: 401 layers, 71753737 parameters, 71753721 gradients
#
# Transferred 651/657 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir HuBMAP/yolov8x-seg', view at http://localhost:6006/
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to yolov8n.pt...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 294MB/s]
# AMP: checks passed ✅
# train: Scanning /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/labels... 1388 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1388/1388 [06:20<00:00,  3.64it/s]
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/005715f0a313.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/01a7fca6263b.tif: 7 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/025ec20b8b73.tif: 7 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/02cf5c2db152.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/033a656390b2.tif: 4 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/0672b96aaccc.tif: 4 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/07b809228ef4.tif: 4 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/0a631efbc3e4.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/0a993633aa5e.tif: 7 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/0ba172f33ea6.tif: 8 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/0bc3e1a729e4.tif: 7 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/0ce440ad7080.tif: 13 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/0f6e1cb07f74.tif: 8 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/0f960d864969.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/15262223b967.tif: 11 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/189064c6a137.tif: 6 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/1aeae455caeb.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/1b5da995f08e.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/1c0295c1d01d.tif: 3 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/1fc1c6cc515a.tif: 11 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/20113c729fe4.tif: 10 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/228da07bf8d9.tif: 7 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/23c30a541c7a.tif: 12 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/23c98917da69.tif: 6 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/270f0c7b0901.tif: 9 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/2ac4cfbb7405.tif: 4 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/2c369bf03bd4.tif: 7 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/314a25a7f92d.tif: 7 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/326c9663d95d.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/328a651a4ca7.tif: 12 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/329d9bc6f0f8.tif: 8 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/3398c337fe7a.tif: 8 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/340bbab914db.tif: 10 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/36be7dacbabf.tif: 11 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/38ff92c9ae72.tif: 22 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/391e9699357a.tif: 4 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/3936393ac567.tif: 2 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/3a93b29c72f2.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/3b8d1919d08e.tif: 3 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/3ca3b1b0db63.tif: 6 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/41146970649b.tif: 17 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/4142122db8e4.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/4399be208888.tif: 13 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/43ba93d8284d.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/45d42de2cb89.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/4960cdc6a274.tif: 2 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/4995f7836ec4.tif: 3 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/4a4820ef318c.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/4c058755d597.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/4e8b6849684d.tif: 10 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/501398697fc1.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/5047c7523e09.tif: 7 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/523a3912a7ee.tif: 12 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/5384b927f5b3.tif: 9 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/56102e85ff9f.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/59c99a7cd635.tif: 2 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/5c04198743a5.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/5e72a0265b2f.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/611aee20c207.tif: 11 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/68c4d1b29b13.tif: 8 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/6b1e4cea2071.tif: 7 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/6bfe9903a1cf.tif: 8 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/6d1315ab9ef7.tif: 7 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/6e74e333e5e4.tif: 5 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/6f77355f4181.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/71cd41c93924.tif: 11 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/720c0fa5ce8e.tif: 3 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/7292fe2d34d6.tif: 5 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/74e6545e7553.tif: 2 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/76e5b8a1caa1.tif: 9 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/7cb715d5413c.tif: 15 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/83a7f8ea3f09.tif: 2 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/84a3f37bf808.tif: 8 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/85affadde232.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/85f5c8b8e408.tif: 7 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/85fae4b2ca7c.tif: 2 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/861ffbc05b45.tif: 13 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/88614cbaa57c.tif: 8 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/8b29a4cb940e.tif: 6 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/8b33e8e0f0a1.tif: 15 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/8ebea8a23178.tif: 9 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/910b93e1cf28.tif: 9 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/92450a58e849.tif: 12 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/932c4fa02fee.tif: 18 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/94dd41f92b1d.tif: 6 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/99ddcf7fb9a3.tif: 4 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/9a4ac92edd79.tif: 12 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/9a4d59b6c3ec.tif: 17 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/a0fed17a5bc6.tif: 4 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/a12848a1b5f9.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/a27ffddbba42.tif: 3 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/a661cbfc8464.tif: 10 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/aa05d1efb6bc.tif: 6 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/ace43628b108.tif: 14 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/adadaeaa3635.tif: 11 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/b04db3efff0a.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/b29ab50ca7aa.tif: 6 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/b987af6e6106.tif: 2 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/ba5cffc61dce.tif: 8 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/be0d76907fd8.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/bf0f8e9bf257.tif: 9 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/bffe164b7f65.tif: 6 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/c2731b6c0c17.tif: 9 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/c3e34170ff28.tif: 7 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/c738789588f9.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/cc103e610139.tif: 12 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/cc8bdabbc3eb.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/d0d0fda7789f.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/d17335683f96.tif: 4 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/d4a6a9e8d85e.tif: 8 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/d6bd77533b2b.tif: 8 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/d82695d80caf.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/d873758275c6.tif: 12 duplicate labels removed
# train: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/images/d9547a630fab.tif: 8 duplicate labels removed
# train: New cache created: /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/val/labels... 245 images, 0 backgrounds, 0 corrupt: 100%|██████████| 245/245 [01:17<00:00,  3.18it/s]
# val: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/val/images/da9507215057.tif: 8 duplicate labels removed
# val: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/val/images/dbf5ec194977.tif: 7 duplicate labels removed
# val: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/val/images/dc0b64e2a3a6.tif: 12 duplicate labels removed
# val: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/val/images/e52522470fea.tif: 4 duplicate labels removed
# val: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/val/images/e9c9c5fb7aef.tif: 1 duplicate labels removed
# val: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/val/images/ef39b81a7917.tif: 1 duplicate labels removed
# val: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/val/images/f217dcd37517.tif: 10 duplicate labels removed
# val: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/val/images/f53f64d220e3.tif: 3 duplicate labels removed
# val: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/val/images/f9faf12fc07b.tif: 4 duplicate labels removed
# val: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/val/images/fa10ae8f9fec.tif: 7 duplicate labels removed
# val: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/val/images/fa6a66f01888.tif: 11 duplicate labels removed
# val: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/val/images/fbe845f13c20.tif: 8 duplicate labels removed
# val: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/val/images/fce9ad75428d.tif: 9 duplicate labels removed
# val: WARNING ⚠️ /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/val/images/ffd3d193c71e.tif: 2 duplicate labels removed
# val: New cache created: /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/val/labels.cache
# Plotting labels to HuBMAP/yolov8x-seg/labels.jpg...
# optimizer: SGD(lr=0.005, momentum=0.947) with parameter groups 106 weight(decay=0.0), 117 weight(decay=0.005), 116 bias(decay=0.0)
# Image sizes 512 train, 512 val
# Using 4 dataloader workers
# Logging results to HuBMAP/yolov8x-seg
# Starting training for 60 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        1/60      9.84G      2.282      3.681      3.133        1.7        142        512: 100%|██████████| 87/87 [01:42<00:00,  1.17s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:08<00:00,  1.02s/it]
#                    all        245       2370      0.556      0.231       0.17      0.105      0.546      0.228      0.167     0.0988
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        2/60        10G        1.8      2.599       2.04      1.361        172        512: 100%|██████████| 87/87 [01:33<00:00,  1.07s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:08<00:00,  1.03s/it]
#                    all        245       2370       0.39      0.378      0.349      0.243      0.396      0.383      0.356      0.235
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        3/60      10.4G      1.694       2.36      1.763      1.266        175        512: 100%|██████████| 87/87 [01:33<00:00,  1.07s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:08<00:00,  1.06s/it]
#                    all        245       2370      0.449      0.437      0.422      0.293      0.455      0.442      0.427      0.284
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        4/60      10.3G      1.661      2.258      1.586      1.241        138        512: 100%|██████████| 87/87 [01:32<00:00,  1.07s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:08<00:00,  1.01s/it]
#                    all        245       2370      0.491      0.457      0.443      0.302      0.499      0.471      0.456      0.307
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        5/60      10.3G      1.645      2.237      1.495      1.222        155        512: 100%|██████████| 87/87 [01:32<00:00,  1.07s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:08<00:00,  1.03s/it]
#                    all        245       2370      0.556      0.473      0.497      0.332      0.565      0.475      0.499      0.316
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        6/60      9.95G      1.618       2.18      1.455      1.215        202        512: 100%|██████████| 87/87 [01:32<00:00,  1.06s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:08<00:00,  1.02s/it]
#                    all        245       2370      0.488      0.512      0.477      0.333       0.49      0.513       0.48      0.321
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        7/60      10.3G      1.605      2.168      1.413      1.204        193        512: 100%|██████████| 87/87 [01:32<00:00,  1.07s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:07<00:00,  1.00it/s]
#                    all        245       2370      0.558       0.49      0.504      0.348       0.57      0.491      0.503      0.326
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        8/60      10.2G      1.594      2.136      1.409      1.207        127        512: 100%|██████████| 87/87 [01:32<00:00,  1.07s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:08<00:00,  1.01s/it]
#                    all        245       2370      0.531      0.492      0.482       0.33      0.532      0.494      0.485      0.314
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        9/60      10.4G      1.578      2.089      1.365      1.202        168        512: 100%|██████████| 87/87 [01:31<00:00,  1.06s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:08<00:00,  1.03s/it]
#                    all        245       2370      0.522      0.554       0.53      0.361      0.523      0.557       0.53       0.35
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       10/60      10.3G      1.579      2.085       1.33      1.192        146        512: 100%|██████████| 87/87 [01:32<00:00,  1.07s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:08<00:00,  1.00s/it]
#                    all        245       2370      0.538      0.532      0.513      0.346      0.554      0.527      0.512      0.333
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       11/60      10.2G      1.559      2.072      1.341      1.186        185        512: 100%|██████████| 87/87 [01:31<00:00,  1.06s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:08<00:00,  1.01s/it]
#                    all        245       2370      0.518      0.523      0.515      0.352      0.518      0.523      0.515      0.329
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       12/60      10.2G      1.547      2.042      1.294      1.181        118        512: 100%|██████████| 87/87 [01:32<00:00,  1.06s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:08<00:00,  1.01s/it]
#                    all        245       2370      0.533      0.522       0.52      0.361      0.538      0.525      0.518      0.348
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       13/60      10.2G      1.522      2.014       1.27      1.165        187        512: 100%|██████████| 87/87 [01:32<00:00,  1.06s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:08<00:00,  1.02s/it]
#                    all        245       2370      0.503      0.523      0.522      0.362      0.499       0.52      0.519      0.352
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       14/60      9.94G      1.535      2.025      1.291      1.176        158        512: 100%|██████████| 87/87 [01:33<00:00,  1.07s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:07<00:00,  1.00it/s]
#                    all        245       2370      0.527      0.562      0.542       0.38      0.527      0.559      0.541      0.353
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       15/60      10.2G      1.531      2.038       1.27      1.167        119        512: 100%|██████████| 87/87 [01:33<00:00,  1.07s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:08<00:00,  1.01s/it]
#                    all        245       2370      0.552      0.545      0.524      0.362      0.555      0.549      0.534      0.355
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       16/60      10.2G      1.516      1.991      1.251      1.168        127        512: 100%|██████████| 87/87 [01:32<00:00,  1.06s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:08<00:00,  1.01s/it]
#                    all        245       2370      0.546      0.563      0.537      0.372      0.553       0.57      0.544      0.368
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       17/60      10.2G      1.511      1.999       1.24      1.163        182        512: 100%|██████████| 87/87 [01:33<00:00,  1.07s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:08<00:00,  1.01s/it]
#                    all        245       2370      0.543       0.57      0.532      0.365      0.615      0.514      0.526      0.348
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       18/60      10.1G      1.486      1.974      1.222      1.153        202        512: 100%|██████████| 87/87 [01:32<00:00,  1.06s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:08<00:00,  1.00s/it]
#                    all        245       2370       0.57      0.554      0.562      0.401      0.573      0.557      0.565      0.395
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       19/60      10.3G      1.488      1.977      1.196      1.139        122        512: 100%|██████████| 87/87 [01:32<00:00,  1.07s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:08<00:00,  1.02s/it]
#                    all        245       2370      0.537      0.521      0.523      0.367       0.54      0.525      0.524      0.359
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       20/60      10.3G      1.475      1.952      1.194      1.136        161        512: 100%|██████████| 87/87 [01:32<00:00,  1.07s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:08<00:00,  1.02s/it]
#                    all        245       2370      0.553      0.514      0.526      0.364      0.555      0.517      0.531      0.356
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       21/60      9.96G      1.459      1.923      1.188      1.127        205        512: 100%|██████████| 87/87 [01:32<00:00,  1.06s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:07<00:00,  1.00it/s]
#                    all        245       2370      0.542      0.526      0.494      0.346      0.553      0.529      0.504      0.335
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       22/60      9.95G      1.457      1.935      1.149      1.132        135        512: 100%|██████████| 87/87 [01:32<00:00,  1.06s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:08<00:00,  1.01s/it]
#                    all        245       2370      0.569      0.573       0.54      0.373      0.564      0.567      0.531       0.35
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       23/60      10.4G      1.444      1.891      1.124      1.124        159        512: 100%|██████████| 87/87 [01:32<00:00,  1.07s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:08<00:00,  1.02s/it]
#                    all        245       2370      0.566      0.554      0.539       0.38       0.57      0.555      0.539      0.374
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       24/60      10.2G      1.431      1.899      1.127      1.121        166        512: 100%|██████████| 87/87 [01:32<00:00,  1.07s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:16<00:00,  2.12s/it]
#                    all        245       2370      0.587      0.556      0.557      0.385      0.582      0.549      0.551      0.372
# Stopping training early as no improvement observed in last 6 epochs. Best results observed at epoch 18, best model saved as best.pt.
# To update EarlyStopping(patience=6) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 24 epochs completed in 0.703 hours.
# Optimizer stripped from HuBMAP/yolov8x-seg/weights/last.pt, 143.9MB
# Optimizer stripped from HuBMAP/yolov8x-seg/weights/best.pt, 143.9MB
#
# Validating HuBMAP/yolov8x-seg/weights/best.pt...
# Ultralytics YOLOv8.0.131 🚀 Python-3.10.6 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8x-seg summary (fused): 295 layers, 71723545 parameters, 0 gradients
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:16<00:00,  2.06s/it]
#                    all        245       2370       0.57      0.554      0.562        0.4      0.572      0.557      0.564      0.396
#           blood_vessel        245       2159      0.516      0.673      0.613      0.309      0.523      0.682      0.622      0.288
#             glomerulus        245         73      0.896      0.822      0.922      0.802      0.896      0.822      0.919      0.815
#                 unsure        245        138      0.297      0.167       0.15     0.0892      0.297      0.167       0.15      0.084
# Speed: 0.9ms preprocess, 21.7ms inference, 0.0ms loss, 2.7ms postprocess per image
# Results saved to HuBMAP/yolov8x-seg

# %%
files.download('/content/HuBMAP/yolov8x-seg/weights/best.pt')

# %%
import matplotlib.pyplot as plt
from PIL import Image

# %%
dirlist = os.listdir("/gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/val/images")
print(dirlist[:5])
# Out:
# ['d9808586aef2.tif', 'da054a47370e.tif', 'da1c6d6657e9.tif', 'da2863316247.tif', 'da3180fa5201.tif']

# %%
model = YOLO("/content/HuBMAP/yolov8x-seg/weights/best.pt")
history = model.predict("/gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/val/images/fbd64e93f84d.tif")[0]
image = history.plot()
plt.imshow(image)
plt.show()
# Out:
# image 1/1 /gdrive/MyDrive/DATA/HuBMAP/coco_85train_dataset4/dataset/val/images/fbd64e93f84d.tif: 512x512 8 blood_vessels, 67.7ms
# Speed: 1.7ms preprocess, 67.7ms inference, 10.7ms postprocess per image at shape (1, 3, 512, 512)

# %%
F1_curve = Image.open("/content/HuBMAP/yolov8x-seg/results.png")
plt.figure(figsize=(15,20))
plt.imshow(F1_curve)
plt.show()

# %%
mask_p = Image.open('/content/HuBMAP/yolov8x-seg/MaskP_curve.png')
plt.figure(figsize=(15,20))
plt.imshow(mask_p)
plt.show()

# %%
mask_r = Image.open('/content/HuBMAP/yolov8x-seg/MaskR_curve.png')
plt.figure(figsize=(15,20))
plt.imshow(mask_r)
plt.show()

# %%
mask_pr = Image.open('/content/HuBMAP/yolov8x-seg/MaskPR_curve.png')
plt.figure(figsize=(15,20))
plt.imshow(mask_pr)
plt.show()

# %%
my_model = YOLO('/content/HuBMAP/yolov8x-seg/weights/best.pt')
results = list(my_model('/gdrive/MyDrive/DATA/HuBMAP/test/72e40acccadf.tif', conf=0.05))
result = results[0]
# Out:
# image 1/1 /gdrive/MyDrive/DATA/HuBMAP/test/72e40acccadf.tif: 512x512 38 blood_vessels, 3 glomeruluss, 72.5ms
# Speed: 1.3ms preprocess, 72.5ms inference, 3.5ms postprocess per image at shape (1, 3, 512, 512)

# %%
print(result.masks.data.shape)
# Out:
# torch.Size([16, 512, 512])

# %%
results = pd.read_csv("/content/HuBMAP/yolov8x-seg/results.csv")
results.head()
results.to_csv('/gdrive/MyDrive/DATA/HuBMAP/Results/is_yolov8_v25_20230729.csv')

# %%
#plt.imshow(result.masks.data)
#plt.show()

# %%
results
# Out:
#                       epoch           train/box_loss           train/seg_loss  \
# 0                         0                   2.2818                   3.6805
# 1                         1                   1.8001                   2.5989
# 2                         2                   1.6939                   2.3605
# 3                         3                   1.6609                   2.2577
# 4                         4                   1.6451                   2.2368
# 5                         5                   1.6183                   2.1799
# 6                         6                   1.6048                   2.1680
# 7                         7                   1.5936                   2.1358
# 8                         8                   1.5783                   2.0891
# 9                         9                   1.5790                   2.0847
# 10                       10                   1.5589                   2.0720
# 11                       11                   1.5475                   2.0423
# 12                       12                   1.5224                   2.0143
# 13                       13                   1.5352                   2.0251
# 14                       14                   1.5305                   2.0378
# 15                       15                   1.5161                   1.9905
# 16                       16                   1.5113                   1.9993
# 17                       17                   1.4860                   1.9744
# 18                       18                   1.4882                   1.9769
# 19                       19                   1.4745                   1.9517
# 20                       20                   1.4588                   1.9228
# 21                       21                   1.4575                   1.9351
# 22                       22                   1.4443                   1.8911
# 23                       23                   1.4307                   1.8987
#
#              train/cls_loss           train/dfl_loss     metrics/precision(B)  \
# 0                    3.1328                   1.7002                  0.55561
# 1                    2.0400                   1.3613                  0.39044
# 2                    1.7628                   1.2663                  0.44892
# 3                    1.5855                   1.2411                  0.49088
# 4                    1.4953                   1.2223                  0.55634
# 5                    1.4545                   1.2145                  0.48846
# 6                    1.4133                   1.2036                  0.55761
# 7                    1.4094                   1.2066                  0.53107
# 8                    1.3646                   1.2023                  0.52155
# 9                    1.3305                   1.1915                  0.53779
# 10                   1.3415                   1.1856                  0.51845
# 11                   1.2941                   1.1808                  0.53338
# 12                   1.2698                   1.1646                  0.50256
# 13                   1.2906                   1.1755                  0.52702
# 14                   1.2700                   1.1668                  0.55185
# 15                   1.2510                   1.1683                  0.54602
# 16                   1.2400                   1.1631                  0.54277
# 17                   1.2217                   1.1525                  0.57038
# 18                   1.1956                   1.1386                  0.53652
# 19                   1.1942                   1.1358                  0.55309
# 20                   1.1881                   1.1267                  0.54219
# 21                   1.1488                   1.1321                  0.56861
# 22                   1.1236                   1.1242                  0.56558
# 23                   1.1272                   1.1210                  0.58729
#
#           metrics/recall(B)         metrics/mAP50(B)      metrics/mAP50-95(B)  \
# 0                   0.23096                  0.17022                  0.10470
# 1                   0.37808                  0.34945                  0.24262
# 2                   0.43730                  0.42174                  0.29276
# 3                   0.45688                  0.44348                  0.30205
# 4                   0.47318                  0.49672                  0.33206
# 5                   0.51227                  0.47714                  0.33266
# 6                   0.49001                  0.50422                  0.34801
# 7                   0.49224                  0.48164                  0.32987
# 8                   0.55426                  0.53011                  0.36114
# 9                   0.53200                  0.51267                  0.34600
# 10                  0.52344                  0.51478                  0.35179
# 11                  0.52180                  0.52025                  0.36064
# 12                  0.52316                  0.52217                  0.36183
# 13                  0.56222                  0.54244                  0.38025
# 14                  0.54455                  0.52370                  0.36241
# 15                  0.56285                  0.53740                  0.37241
# 16                  0.56964                  0.53241                  0.36470
# 17                  0.55417                  0.56203                  0.40073
# 18                  0.52104                  0.52291                  0.36730
# 19                  0.51378                  0.52599                  0.36404
# 20                  0.52608                  0.49450                  0.34588
# 21                  0.57333                  0.54040                  0.37286
# 22                  0.55371                  0.53854                  0.38021
# 23                  0.55565                  0.55662                  0.38469
#
#        metrics/precision(M)        metrics/recall(M)         metrics/mAP50(M)  \
# 0                   0.54642                  0.22810                  0.16720
# 1                   0.39584                  0.38270                  0.35583
# 2                   0.45451                  0.44239                  0.42727
# 3                   0.49901                  0.47119                  0.45619
# 4                   0.56504                  0.47516                  0.49855
# 5                   0.49027                  0.51349                  0.48024
# 6                   0.56976                  0.49132                  0.50338
# 7                   0.53211                  0.49394                  0.48479
# 8                   0.52346                  0.55675                  0.52953
# 9                   0.55397                  0.52749                  0.51188
# 10                  0.51845                  0.52344                  0.51478
# 11                  0.53755                  0.52504                  0.51817
# 12                  0.49948                  0.52020                  0.51939
# 13                  0.52735                  0.55907                  0.54118
# 14                  0.55542                  0.54934                  0.53351
# 15                  0.55324                  0.56959                  0.54386
# 16                  0.61498                  0.51412                  0.52603
# 17                  0.57286                  0.55741                  0.56457
# 18                  0.53950                  0.52474                  0.52373
# 19                  0.55495                  0.51687                  0.53150
# 20                  0.55300                  0.52925                  0.50376
# 21                  0.56448                  0.56691                  0.53149
# 22                  0.57020                  0.55540                  0.53925
# 23                  0.58161                  0.54877                  0.55069
#
#         metrics/mAP50-95(M)             val/box_loss             val/seg_loss  \
# 0                   0.09879                   1.9939                   2.9925
# 1                   0.23531                   1.7902                   2.5514
# 2                   0.28375                   1.7918                   2.4236
# 3                   0.30717                   1.8707                   2.3751
# 4                   0.31633                   1.6511                   2.3147
# 5                   0.32082                   1.6608                   2.3383
# 6                   0.32568                   1.6634                   2.3665
# 7                   0.31413                   1.7126                   2.4690
# 8                   0.35031                   1.6184                   2.3048
# 9                   0.33259                   1.6310                   2.3203
# 10                  0.32912                   1.6466                   2.3580
# 11                  0.34827                   1.6250                   2.2821
# 12                  0.35177                   1.6549                   2.2596
# 13                  0.35308                   1.6366                   2.3302
# 14                  0.35538                   1.6386                   2.1583
# 15                  0.36785                   1.6007                   2.1134
# 16                  0.34752                   1.6545                   2.4419
# 17                  0.39504                   1.5883                   2.1760
# 18                  0.35912                   1.6541                   2.2356
# 19                  0.35607                   1.6532                   2.2252
# 20                  0.33521                   1.7223                   2.4083
# 21                  0.35038                   1.6248                   2.3104
# 22                  0.37380                   1.5955                   2.1788
# 23                  0.37164                   1.6297                   2.3236
#
#                val/cls_loss             val/dfl_loss                   lr/pg0  \
# 0                    2.2031                   1.5752                 0.068697
# 1                    1.8518                   1.4069                 0.037028
# 2                    1.8837                   1.3581                 0.005351
# 3                    1.7024                   1.3771                 0.004969
# 4                    1.5796                   1.2724                 0.004969
# 5                    1.6244                   1.2807                 0.004946
# 6                    1.4662                   1.2871                 0.004916
# 7                    1.5449                   1.3094                 0.004879
# 8                    1.4485                   1.2536                 0.004836
# 9                    1.4173                   1.2888                 0.004786
# 10                   1.4112                   1.2687                 0.004730
# 11                   1.3979                   1.2587                 0.004668
# 12                   1.3945                   1.2691                 0.004601
# 13                   1.3524                   1.2620                 0.004527
# 14                   1.3911                   1.2765                 0.004448
# 15                   1.3452                   1.2508                 0.004364
# 16                   1.3634                   1.2701                 0.004275
# 17                   1.3012                   1.2408                 0.004181
# 18                   1.3931                   1.2637                 0.004083
# 19                   1.3794                   1.2651                 0.003980
# 20                   1.4079                   1.2953                 0.003873
# 21                   1.3385                   1.2602                 0.003762
# 22                   1.3344                   1.2602                 0.003649
# 23                   1.3062                   1.2684                 0.003532
#
#                      lr/pg1                   lr/pg2
# 0                  0.001648                 0.001648
# 1                  0.003312                 0.003312
# 2                  0.004967                 0.004967
# 3                  0.004969                 0.004969
# 4                  0.004969                 0.004969
# 5                  0.004946                 0.004946
# 6                  0.004916                 0.004916
# 7                  0.004879                 0.004879
# 8                  0.004836                 0.004836
# 9                  0.004786                 0.004786
# 10                 0.004730                 0.004730
# 11                 0.004668                 0.004668
# 12                 0.004601                 0.004601
# 13                 0.004527                 0.004527
# 14                 0.004448                 0.004448
# 15                 0.004364                 0.004364
# 16                 0.004275                 0.004275
# 17                 0.004181                 0.004181
# 18                 0.004083                 0.004083
# 19                 0.003980                 0.003980
# 20                 0.003873                 0.003873
# 21                 0.003762                 0.003762
# 22                 0.003649                 0.003649
# 23                 0.003532                 0.003532

# %%
plt.figure

# %%
plt.figure(figsize=(15,20))
confusion_matrix = Image.open("/content/HuBMAP/yolov8x-seg/confusion_matrix.png")
plt.imshow(confusion_matrix)
plt.show()

# %%
plt.figure(figsize=(15,20))
confusion_matrix = Image.open("/content/HuBMAP/yolov8x-seg/confusion_matrix_normalized.png")
plt.imshow(confusion_matrix)
plt.show()

# %%
results = pd.read_csv("/gdrive/MyDrive/DATA/HuBMAP/Results/is_yolov8_v25_20230729.csv",index_col=0)
results.columns = results.columns.str.strip()

results
# Out:
#     epoch  train/box_loss  train/seg_loss  train/cls_loss  train/dfl_loss  \
# 0       0          2.2818          3.6805          3.1328          1.7002
# 1       1          1.8001          2.5989          2.0400          1.3613
# 2       2          1.6939          2.3605          1.7628          1.2663
# 3       3          1.6609          2.2577          1.5855          1.2411
# 4       4          1.6451          2.2368          1.4953          1.2223
# 5       5          1.6183          2.1799          1.4545          1.2145
# 6       6          1.6048          2.1680          1.4133          1.2036
# 7       7          1.5936          2.1358          1.4094          1.2066
# 8       8          1.5783          2.0891          1.3646          1.2023
# 9       9          1.5790          2.0847          1.3305          1.1915
# 10     10          1.5589          2.0720          1.3415          1.1856
# 11     11          1.5475          2.0423          1.2941          1.1808
# 12     12          1.5224          2.0143          1.2698          1.1646
# 13     13          1.5352          2.0251          1.2906          1.1755
# 14     14          1.5305          2.0378          1.2700          1.1668
# 15     15          1.5161          1.9905          1.2510          1.1683
# 16     16          1.5113          1.9993          1.2400          1.1631
# 17     17          1.4860          1.9744          1.2217          1.1525
# 18     18          1.4882          1.9769          1.1956          1.1386
# 19     19          1.4745          1.9517          1.1942          1.1358
# 20     20          1.4588          1.9228          1.1881          1.1267
# 21     21          1.4575          1.9351          1.1488          1.1321
# 22     22          1.4443          1.8911          1.1236          1.1242
# 23     23          1.4307          1.8987          1.1272          1.1210
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0                0.55561            0.23096           0.17022
# 1                0.39044            0.37808           0.34945
# 2                0.44892            0.43730           0.42174
# 3                0.49088            0.45688           0.44348
# 4                0.55634            0.47318           0.49672
# 5                0.48846            0.51227           0.47714
# 6                0.55761            0.49001           0.50422
# 7                0.53107            0.49224           0.48164
# 8                0.52155            0.55426           0.53011
# 9                0.53779            0.53200           0.51267
# 10               0.51845            0.52344           0.51478
# 11               0.53338            0.52180           0.52025
# 12               0.50256            0.52316           0.52217
# 13               0.52702            0.56222           0.54244
# 14               0.55185            0.54455           0.52370
# 15               0.54602            0.56285           0.53740
# 16               0.54277            0.56964           0.53241
# 17               0.57038            0.55417           0.56203
# 18               0.53652            0.52104           0.52291
# 19               0.55309            0.51378           0.52599
# 20               0.54219            0.52608           0.49450
# 21               0.56861            0.57333           0.54040
# 22               0.56558            0.55371           0.53854
# 23               0.58729            0.55565           0.55662
#
#     metrics/mAP50-95(B)  metrics/precision(M)  metrics/recall(M)  \
# 0               0.10470               0.54642            0.22810
# 1               0.24262               0.39584            0.38270
# 2               0.29276               0.45451            0.44239
# 3               0.30205               0.49901            0.47119
# 4               0.33206               0.56504            0.47516
# 5               0.33266               0.49027            0.51349
# 6               0.34801               0.56976            0.49132
# 7               0.32987               0.53211            0.49394
# 8               0.36114               0.52346            0.55675
# 9               0.34600               0.55397            0.52749
# 10              0.35179               0.51845            0.52344
# 11              0.36064               0.53755            0.52504
# 12              0.36183               0.49948            0.52020
# 13              0.38025               0.52735            0.55907
# 14              0.36241               0.55542            0.54934
# 15              0.37241               0.55324            0.56959
# 16              0.36470               0.61498            0.51412
# 17              0.40073               0.57286            0.55741
# 18              0.36730               0.53950            0.52474
# 19              0.36404               0.55495            0.51687
# 20              0.34588               0.55300            0.52925
# 21              0.37286               0.56448            0.56691
# 22              0.38021               0.57020            0.55540
# 23              0.38469               0.58161            0.54877
#
#     metrics/mAP50(M)  metrics/mAP50-95(M)  val/box_loss  val/seg_loss  \
# 0            0.16720              0.09879        1.9939        2.9925
# 1            0.35583              0.23531        1.7902        2.5514
# 2            0.42727              0.28375        1.7918        2.4236
# 3            0.45619              0.30717        1.8707        2.3751
# 4            0.49855              0.31633        1.6511        2.3147
# 5            0.48024              0.32082        1.6608        2.3383
# 6            0.50338              0.32568        1.6634        2.3665
# 7            0.48479              0.31413        1.7126        2.4690
# 8            0.52953              0.35031        1.6184        2.3048
# 9            0.51188              0.33259        1.6310        2.3203
# 10           0.51478              0.32912        1.6466        2.3580
# 11           0.51817              0.34827        1.6250        2.2821
# 12           0.51939              0.35177        1.6549        2.2596
# 13           0.54118              0.35308        1.6366        2.3302
# 14           0.53351              0.35538        1.6386        2.1583
# 15           0.54386              0.36785        1.6007        2.1134
# 16           0.52603              0.34752        1.6545        2.4419
# 17           0.56457              0.39504        1.5883        2.1760
# 18           0.52373              0.35912        1.6541        2.2356
# 19           0.53150              0.35607        1.6532        2.2252
# 20           0.50376              0.33521        1.7223        2.4083
# 21           0.53149              0.35038        1.6248        2.3104
# 22           0.53925              0.37380        1.5955        2.1788
# 23           0.55069              0.37164        1.6297        2.3236
#
#     val/cls_loss  val/dfl_loss    lr/pg0    lr/pg1    lr/pg2
# 0         2.2031        1.5752  0.068697  0.001648  0.001648
# 1         1.8518        1.4069  0.037028  0.003312  0.003312
# 2         1.8837        1.3581  0.005351  0.004967  0.004967
# 3         1.7024        1.3771  0.004969  0.004969  0.004969
# 4         1.5796        1.2724  0.004969  0.004969  0.004969
# 5         1.6244        1.2807  0.004946  0.004946  0.004946
# 6         1.4662        1.2871  0.004916  0.004916  0.004916
# 7         1.5449        1.3094  0.004879  0.004879  0.004879
# 8         1.4485        1.2536  0.004836  0.004836  0.004836
# 9         1.4173        1.2888  0.004786  0.004786  0.004786
# 10        1.4112        1.2687  0.004730  0.004730  0.004730
# 11        1.3979        1.2587  0.004668  0.004668  0.004668
# 12        1.3945        1.2691  0.004601  0.004601  0.004601
# 13        1.3524        1.2620  0.004527  0.004527  0.004527
# 14        1.3911        1.2765  0.004448  0.004448  0.004448
# 15        1.3452        1.2508  0.004364  0.004364  0.004364
# 16        1.3634        1.2701  0.004275  0.004275  0.004275
# 17        1.3012        1.2408  0.004181  0.004181  0.004181
# 18        1.3931        1.2637  0.004083  0.004083  0.004083
# 19        1.3794        1.2651  0.003980  0.003980  0.003980
# 20        1.4079        1.2953  0.003873  0.003873  0.003873
# 21        1.3385        1.2602  0.003762  0.003762  0.003762
# 22        1.3344        1.2602  0.003649  0.003649  0.003649
# 23        1.3062        1.2684  0.003532  0.003532  0.003532

# %%
plt.figure(figsize=(15,15))

loss_labels = results.columns.tolist()[1:5] + results.columns.tolist()[13:17]
for idx in range(4):
  plt.subplot(2,2,idx+1)
  plt.plot(results['epoch'],results[loss_labels[idx]],label = loss_labels[idx])
  plt.plot(results['epoch'],results[loss_labels[idx+4]],label = loss_labels[idx+4])
  plt.legend(loc='upper right')
  plt.xlabel('epoch')
  plt.ylabel(loss_labels[idx].split('/')[1])
  plt.title(loss_labels[idx].split('/')[1])



plt.show();

# %%
results
# Out:
#     epoch  train/box_loss  train/seg_loss  train/cls_loss  train/dfl_loss  \
# 0       0          2.2818          3.6805          3.1328          1.7002
# 1       1          1.8001          2.5989          2.0400          1.3613
# 2       2          1.6939          2.3605          1.7628          1.2663
# 3       3          1.6609          2.2577          1.5855          1.2411
# 4       4          1.6451          2.2368          1.4953          1.2223
# 5       5          1.6183          2.1799          1.4545          1.2145
# 6       6          1.6048          2.1680          1.4133          1.2036
# 7       7          1.5936          2.1358          1.4094          1.2066
# 8       8          1.5783          2.0891          1.3646          1.2023
# 9       9          1.5790          2.0847          1.3305          1.1915
# 10     10          1.5589          2.0720          1.3415          1.1856
# 11     11          1.5475          2.0423          1.2941          1.1808
# 12     12          1.5224          2.0143          1.2698          1.1646
# 13     13          1.5352          2.0251          1.2906          1.1755
# 14     14          1.5305          2.0378          1.2700          1.1668
# 15     15          1.5161          1.9905          1.2510          1.1683
# 16     16          1.5113          1.9993          1.2400          1.1631
# 17     17          1.4860          1.9744          1.2217          1.1525
# 18     18          1.4882          1.9769          1.1956          1.1386
# 19     19          1.4745          1.9517          1.1942          1.1358
# 20     20          1.4588          1.9228          1.1881          1.1267
# 21     21          1.4575          1.9351          1.1488          1.1321
# 22     22          1.4443          1.8911          1.1236          1.1242
# 23     23          1.4307          1.8987          1.1272          1.1210
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0                0.55561            0.23096           0.17022
# 1                0.39044            0.37808           0.34945
# 2                0.44892            0.43730           0.42174
# 3                0.49088            0.45688           0.44348
# 4                0.55634            0.47318           0.49672
# 5                0.48846            0.51227           0.47714
# 6                0.55761            0.49001           0.50422
# 7                0.53107            0.49224           0.48164
# 8                0.52155            0.55426           0.53011
# 9                0.53779            0.53200           0.51267
# 10               0.51845            0.52344           0.51478
# 11               0.53338            0.52180           0.52025
# 12               0.50256            0.52316           0.52217
# 13               0.52702            0.56222           0.54244
# 14               0.55185            0.54455           0.52370
# 15               0.54602            0.56285           0.53740
# 16               0.54277            0.56964           0.53241
# 17               0.57038            0.55417           0.56203
# 18               0.53652            0.52104           0.52291
# 19               0.55309            0.51378           0.52599
# 20               0.54219            0.52608           0.49450
# 21               0.56861            0.57333           0.54040
# 22               0.56558            0.55371           0.53854
# 23               0.58729            0.55565           0.55662
#
#     metrics/mAP50-95(B)  metrics/precision(M)  metrics/recall(M)  \
# 0               0.10470               0.54642            0.22810
# 1               0.24262               0.39584            0.38270
# 2               0.29276               0.45451            0.44239
# 3               0.30205               0.49901            0.47119
# 4               0.33206               0.56504            0.47516
# 5               0.33266               0.49027            0.51349
# 6               0.34801               0.56976            0.49132
# 7               0.32987               0.53211            0.49394
# 8               0.36114               0.52346            0.55675
# 9               0.34600               0.55397            0.52749
# 10              0.35179               0.51845            0.52344
# 11              0.36064               0.53755            0.52504
# 12              0.36183               0.49948            0.52020
# 13              0.38025               0.52735            0.55907
# 14              0.36241               0.55542            0.54934
# 15              0.37241               0.55324            0.56959
# 16              0.36470               0.61498            0.51412
# 17              0.40073               0.57286            0.55741
# 18              0.36730               0.53950            0.52474
# 19              0.36404               0.55495            0.51687
# 20              0.34588               0.55300            0.52925
# 21              0.37286               0.56448            0.56691
# 22              0.38021               0.57020            0.55540
# 23              0.38469               0.58161            0.54877
#
#     metrics/mAP50(M)  metrics/mAP50-95(M)  val/box_loss  val/seg_loss  \
# 0            0.16720              0.09879        1.9939        2.9925
# 1            0.35583              0.23531        1.7902        2.5514
# 2            0.42727              0.28375        1.7918        2.4236
# 3            0.45619              0.30717        1.8707        2.3751
# 4            0.49855              0.31633        1.6511        2.3147
# 5            0.48024              0.32082        1.6608        2.3383
# 6            0.50338              0.32568        1.6634        2.3665
# 7            0.48479              0.31413        1.7126        2.4690
# 8            0.52953              0.35031        1.6184        2.3048
# 9            0.51188              0.33259        1.6310        2.3203
# 10           0.51478              0.32912        1.6466        2.3580
# 11           0.51817              0.34827        1.6250        2.2821
# 12           0.51939              0.35177        1.6549        2.2596
# 13           0.54118              0.35308        1.6366        2.3302
# 14           0.53351              0.35538        1.6386        2.1583
# 15           0.54386              0.36785        1.6007        2.1134
# 16           0.52603              0.34752        1.6545        2.4419
# 17           0.56457              0.39504        1.5883        2.1760
# 18           0.52373              0.35912        1.6541        2.2356
# 19           0.53150              0.35607        1.6532        2.2252
# 20           0.50376              0.33521        1.7223        2.4083
# 21           0.53149              0.35038        1.6248        2.3104
# 22           0.53925              0.37380        1.5955        2.1788
# 23           0.55069              0.37164        1.6297        2.3236
#
#     val/cls_loss  val/dfl_loss    lr/pg0    lr/pg1    lr/pg2
# 0         2.2031        1.5752  0.068697  0.001648  0.001648
# 1         1.8518        1.4069  0.037028  0.003312  0.003312
# 2         1.8837        1.3581  0.005351  0.004967  0.004967
# 3         1.7024        1.3771  0.004969  0.004969  0.004969
# 4         1.5796        1.2724  0.004969  0.004969  0.004969
# 5         1.6244        1.2807  0.004946  0.004946  0.004946
# 6         1.4662        1.2871  0.004916  0.004916  0.004916
# 7         1.5449        1.3094  0.004879  0.004879  0.004879
# 8         1.4485        1.2536  0.004836  0.004836  0.004836
# 9         1.4173        1.2888  0.004786  0.004786  0.004786
# 10        1.4112        1.2687  0.004730  0.004730  0.004730
# 11        1.3979        1.2587  0.004668  0.004668  0.004668
# 12        1.3945        1.2691  0.004601  0.004601  0.004601
# 13        1.3524        1.2620  0.004527  0.004527  0.004527
# 14        1.3911        1.2765  0.004448  0.004448  0.004448
# 15        1.3452        1.2508  0.004364  0.004364  0.004364
# 16        1.3634        1.2701  0.004275  0.004275  0.004275
# 17        1.3012        1.2408  0.004181  0.004181  0.004181
# 18        1.3931        1.2637  0.004083  0.004083  0.004083
# 19        1.3794        1.2651  0.003980  0.003980  0.003980
# 20        1.4079        1.2953  0.003873  0.003873  0.003873
# 21        1.3385        1.2602  0.003762  0.003762  0.003762
# 22        1.3344        1.2602  0.003649  0.003649  0.003649
# 23        1.3062        1.2684  0.003532  0.003532  0.003532
