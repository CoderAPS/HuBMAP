# %% [markdown]
# <a href="https://colab.research.google.com/github/CoderAPS/HuBMAP/blob/main/instance_segmentation_yolov8_v6_20230715.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Medical Instance Segmentation with YOLOv8 version 5
# References:<br>
# https://docs.ultralytics.com/usage/cfg/#tasks <br>
# how YOLO v8 works: https://openmmlab.medium.com/dive-into-yolov8-how-does-this-state-of-the-art-model-work-10f18f74bab1 <br>

# %% [markdown]
# Run 1: <br>
# Split: 0.85 & 0.25, LR0 = 0.01, LRf = 0.001, batch = 16, droupout = 0.4, patience = 6, epoch = 50 (early stopping at epoch 9),   data = /gdrive/MyDrive/DATA/HuBMAP/images

# %%
# Mount google drive
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# !ls /gdrive/MyDrive/DATA/HuBMAP/
# Out:
# annotation_info.csv  masks_white_bkgrnd  sample_submission.csv	train_list.csv
# blue_images	     norm_images	 test			val_list.csv
# images		     polygons.jsonl	 test2			wsi_meta.csv
# images_info.csv      red_images		 test_list.csv
# masks		     Results		 tile_meta.csv

# %%
# !pip install colorama
# Out:
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama
# Successfully installed colorama-0.4.6

# %%
# libraries needed to create the create the dataset in COCO format
from itertools import chain
import json
import os
import glob
import shutil
from tqdm.notebook import tqdm
from colorama import Fore
import yaml
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from PIL import Image
import cv2

# use this code to clear output
from IPython import display
from google.colab import files
#display.clear_output()

# %%
'''
images_info = pd.read_csv('/gdrive/MyDrive/DATA/HuBMAP/images_info.csv',index_col=0)
image_path = images_info.image_path.sample().values[0]

image_1 = Image.open(image_path)
image_1 = np.array(image_1)

image_2 = cv2.imread(image_path)


n1,b1,r1 = nic.process_color(image_1)
n2,b2,r2 = nic.process_color(image_2)


image_1 = Image.fromarray(image_1)
n1 = Image.fromarray(n1)
b1 = Image.fromarray(b1)
r1 = Image.fromarray(r1)

image_1.save('/content/image_1.tif')
n1.save('/content/n1.tif')
b1.save('/content/b1.tif')
r1.save('/content/r1.tif')

cv2.imwrite('/content/image_2.tif',image_2)
cv2.imwrite('/content/n2.tif',n2)
cv2.imwrite('/content/b2.tif',b2)
cv2.imwrite('/content/r2.tif',r2)
'''

image_1 = Image.open('/content/image_1.tif')
n1 = Image.open('/content/n1.tif')
b1 = Image.open('/content/b1.tif')
r1 = Image.open('/content/r1.tif')


image_2 = cv2.imread('/content/image_2.tif')
n2 = cv2.imread('/content/n2.tif')
b2 = cv2.imread('/content/b2.tif')
r2 = cv2.imread('/content/r2.tif')


images_arr_1 = [image_1,n1,b1,r1]
images_arr_2 = [image_2,n2,b2,r2]


image_type = ['Image','cv2']
titles = ['orinal','normalized','blue(H. sep)','red (E. sep)']

plt.figure(figsize=(10,10))

for idx in range(8):
  plt.subplot(2,4,1+idx)

  image = None
  i_type = None
  if idx < 4:
    image = images_arr_1[idx]
    i_type = image_type[0]
  else:
    image = images_arr_2[idx-4]
    i_type = image_type[1]

  plt.imshow(image)
  plt.title(i_type+': ' + titles[idx]) if idx < 4 else plt.title(i_type+': ' + titles[idx-4])

  plt.axis('off')

# %%
# class for creating the dataset
class COCODataset:
    def __init__(self, images_dirpath: str, annotations_filepath: str, length: int = 1633):
        self.train_size = None
        self.val_size = None
        self.length = length
        self.classes = None
        self.labels_counter = None
        self.normalize = None

        self.images_dirpath = images_dirpath
        self.annotations_filepath = annotations_filepath
        self.dataset_dirpath = os.path.join(os.getcwd(), "dataset")
        self.train_dirpath =  os.path.join(self.dataset_dirpath, "train")
        self.val_dirpath =  os.path.join(self.dataset_dirpath, "val")
        self.config_path = os.path.join(self.dataset_dirpath, "coco.yaml")

        self.samples = self.parse_jsonl(annotations_filepath)
        self.classes_dict = {
            "blood_vessel": 0,
            "glomerulus": 1,
            "unsure": 2,
        }

    def __prepare_dirs(self) -> None:
        if not os.path.exists(self.dataset_dirpath):
            os.makedirs(os.path.join(self.train_dirpath, "images"), exist_ok=True)
            os.makedirs(os.path.join(self.train_dirpath, "labels"), exist_ok=True)
            os.makedirs(os.path.join(self.val_dirpath, "images"), exist_ok=True)
            os.makedirs(os.path.join(self.val_dirpath, "labels"), exist_ok=True)
        else:
            raise RuntimeError("Dataset already exists!")

    def __define_splitratio(self) -> None:
        self.train_size = round(self.length * self.train_size)
        self.val_size = self.length - self.train_size
        assert self.train_size + self.val_size == self.length

    def parse_jsonl(self, path: str) -> list[dict, ...]:
        with open(path, 'r') as json_file:
            jsonl_samples = [
                json.loads(line)
                for line in tqdm(
                    json_file, desc="Processing polygons", total=self.length
                )
            ]
        return jsonl_samples

    def __define_paths(self, i: int) -> dict:
        data_path = self.val_dirpath
        if i < self.train_size:
            data_path = self.train_dirpath
        return {
            "images": os.path.join(data_path, "images"),
            "labels": os.path.join(data_path, "labels")
        }

    @staticmethod
    def __get_label_path(paths_dict: dict, identifier: str) -> str:
        return os.path.join(
            paths_dict["labels"],
            f"{identifier}.txt"
        )

    @staticmethod
    def __get_image_path(paths_dict: dict, identifier: str) -> str:
        return os.path.join(
            paths_dict["images"],
            f"{identifier}.tif"
        )

    def __copy_image(self, dst_path: str, identifier: str) -> str:
        shutil.copyfile(
            os.path.join(self.images_dirpath, f"{identifier}.tif"),
            dst_path
        )

    def __copy_label(self, annotations: list, dst_path: str) -> None:
        with open(dst_path, "w") as file:
            for annotation in annotations:
                coordinates = annotation["coordinates"][0]
                label = self.classes_dict[annotation["type"]]
                if label in self.classes:
                    if coordinates:
                        if self.normalize:
                            coordinates = np.array(coordinates) / 512.0
                        coordinates = " ".join(map(str, chain(*coordinates)))
                        file.write(f"{label} {coordinates}\n")
                        self.labels_counter += 1

    def __splitfolders(self):
        for i, line in tqdm(
                enumerate(self.samples),
                desc="Dataset creation", total=self.length
        ):
            self.labels_counter = 0
            identifier = line["id"]
            annotations = line["annotations"]
            paths_dict = self.__define_paths(i)

            dst_image_path = self.__get_image_path(paths_dict, identifier)
            dst_label_path = self.__get_label_path(paths_dict, identifier)

            self.__copy_image(dst_image_path, identifier)
            self.__copy_label(annotations, dst_label_path)

            if self.labels_counter == 0:
                os.remove(dst_image_path)
                os.remove(dst_label_path)

    def __count_dataset(self) -> dict:
        train_images = len(os.listdir(os.path.join(self.train_dirpath, "images")))
        train_labels = len(os.listdir(os.path.join(self.train_dirpath, "labels")))
        val_images = len(os.listdir(os.path.join(self.val_dirpath, "images")))
        val_labels = len(os.listdir(os.path.join(self.val_dirpath, "labels")))
        return {
            "train_images": train_images,
            "train_labels": train_labels,
            "val_images": val_images,
            "val_labels": val_labels
        }

    @staticmethod
    def __check_sanity(count_dict: dict) -> None:
        assert count_dict["train_images"] == count_dict["train_labels"]
        assert count_dict["val_images"] == count_dict["val_labels"]

    def __finalizing(self, count_dict: dict) -> None:
        assert os.path.exists(self.dataset_dirpath)

        example_structure = [
            "dataset",
            "train", "labels", "images",
            "val", "labels", "images"
        ]

        dir_bone = (
            dirname.split("/")[-1]
            for dirname, _, filenames in os.walk(self.dataset_dirpath)
            if dirname.split("/")[-1] in example_structure
        )

        try:
            print("\n~ HuBMAP Dataset Structure ~\n")
            print(
            f"""
          ├── {next(dir_bone)}
          │   │
          │   ├── {next(dir_bone)}
          │   │   └── {next(dir_bone)}
          │   │   └── {next(dir_bone)}
          │   │
          │   ├── {next(dir_bone)}
          │   │   └── {next(dir_bone)}
          │   │   └── {next(dir_bone)}
            """
            )
        except StopIteration as e:
            print(e)
        else:
            print(Fore.GREEN + "-> Success")
            print(Fore.GREEN + f"Train dataset: {count_dict['train_images']}\nVal dataset: {count_dict['val_images']}")

    def get_config(self) ->dict:
        names = ["blood_vessel", "glomerulus", "unsure"]
        return {
            "train": str(self.train_dirpath),
            "val": str(self.val_dirpath),
            "names": [names[i] for i in self.classes]
        }

    @staticmethod
    def display_config(config: dict) -> None:
        print(Fore.BLACK + "\n~ HuBMAP Config Structure ~\n")
        print(
        f"""
      │   │
      │   ├── train
      │   │   └── {config['train']}/images
      │   │
      │   │
      │   ├── val
      │   │   └── {config['val']}/images
      │   │
      │   │
      │   ├── names
      │   │   └── {' '.join(config['names'])}
        """
        )
        print(Fore.GREEN + "-> Success")
        print(Fore.GREEN + f"Number of classes: {len(config['names'])}"
                           f"\nClasses: {' '.join(config['names'])}"
              )

    def write_config(self, config: dict) -> None:
        with open(self.config_path, mode="w") as f:
            yaml.safe_dump(stream=f, data=config)

    def __call__(self, train_size: float,
                 classes: list[int, ...],
                 make_config: bool = True,
                 normalize: bool = True
                ) -> None:

        self.train_size = train_size
        self.classes = classes
        self.normalize = normalize

        self.__define_splitratio()
        self.__prepare_dirs()
        self.__splitfolders()
        count_dict = self.__count_dataset()
        self.__check_sanity(count_dict)
        self.__finalizing(count_dict)

        if make_config:
            config = self.get_config()
            self.write_config(config)
            self.display_config(config)

# %%
# instantiate a COCODataset object
path = '/gdrive/MyDrive/DATA/HuBMAP/'
coco = COCODataset(
    annotations_filepath= path + 'polygons.jsonl',
    images_dirpath=path + 'red_images/'
)
# Out:
# Processing polygons:   0%|          | 0/1633 [00:00<?, ?it/s]

# %%
coco(train_size=0.85, classes=[0, 1, 2])
# Out:
# Dataset creation:   0%|          | 0/1633 [00:00<?, ?it/s]
# ~ HuBMAP Dataset Structure ~
#
#
#           ├── dataset
#           │   │
#           │   ├── val
#           │   │   └── labels
#           │   │   └── images
#           │   │
#           │   ├── train
#           │   │   └── labels
#           │   │   └── images
#
# -> Success
# Train dataset: 1388
# Val dataset: 245
#
# ~ HuBMAP Config Structure ~
#
#
#       │   │
#       │   ├── train
#       │   │   └── /content/dataset/train/images
#       │   │
#       │   │
#       │   ├── val
#       │   │   └── /content/dataset/val/images
#       │   │
#       │   │
#       │   ├── names
#       │   │   └── blood_vessel glomerulus unsure
#
# -> Success
# Number of classes: 3
# Classes: blood_vessel glomerulus unsure

# %%
# !ls dataset
# Out:
# coco.yaml  train  val

# %%
dirlist = os.listdir("/content/dataset/val/images")
random_num = np.random.randint(0, len(dirlist))
image = Image.open("/content/dataset/val/images/"+ dirlist[random_num])
plt.imshow(image)
plt.show()

# %%
# !pip install ultralytics
display.clear_output()

# %%
pip show ultralytics
# Out:
# Name: ultralytics
# Version: 8.0.135
# Summary: Ultralytics YOLOv8 for SOTA object detection, multi-object tracking, instance segmentation, pose estimation and image classification.
# Home-page: https://github.com/ultralytics/ultralytics
# Author: Ultralytics
# Author-email: hello@ultralytics.com
# License: AGPL-3.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: matplotlib, opencv-python, pandas, Pillow, psutil, PyYAML, requests, scipy, seaborn, torch, torchvision, tqdm
# Required-by:

# %%
# !pip install pycocotools
display.clear_output()

# %%
pip show pycocotools
# Out:
# Name: pycocotools
# Version: 2.0.6
# Summary: Official APIs for the MS-COCO dataset
# Home-page: https://github.com/ppwwyyxx/cocoapi
# Author:
# Author-email:
# License: FreeBSD
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: matplotlib, numpy
# Required-by:

# %%
from pycocotools import _mask as coco_mask
import ultralytics
from ultralytics import YOLO

# %%
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.135 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (4 CPUs, 25.5 GB RAM, 26.8/166.8 GB disk)

# %%
# !nvidia-smi
# Out:
# Sat Jul 15 22:27:25 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8     9W /  70W |      3MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
def main():
    model = YOLO("yolov8x-seg.pt")
    model.train(
        # Project
        project="HuBMAP",
        name="yolov8x-seg",

        # Random Seed parameters
        deterministic=True,
        seed=43,

        # Data & model parameters
        data="/content/dataset/coco.yaml",
        save=True,
        save_period=5,
        pretrained=True,
        imgsz=512,

        # Training parameters
        epochs=50,
        batch=16,
        workers=8,
        val=True,
        device= 0,

        # Optimization parameters
        lr0=0.01,
        lrf=0.001,
        patience=6,
        optimizer="SGD",
        momentum=0.947,
        weight_decay=0.0005,
        close_mosaic=3,
        dropout = 0.5
    )

# %%
if __name__ == '__main__':
    main()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8x-seg.pt to yolov8x-seg.pt...
# 100%|██████████| 137M/137M [00:00<00:00, 145MB/s]
# Ultralytics YOLOv8.0.135 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# yolo/engine/trainer: task=segment, mode=train, model=yolov8x-seg.pt, data=/content/dataset/coco.yaml, epochs=50, patience=6, batch=16, imgsz=512, save=True, save_period=5, cache=False, device=0, workers=8, project=HuBMAP, name=yolov8x-seg, exist_ok=False, pretrained=True, optimizer=SGD, verbose=True, seed=43, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic
duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/84a3f37bf808.tif: 8 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/85affadde232.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/85f5c8b8e408.tif: 7 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/85fae4b2ca7c.tif: 2 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/861ffbc05b45.tif: 13 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/88614cbaa57c.tif: 8 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/8b29a4cb940e.tif: 6 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/8b33e8e0f0a1.tif: 15 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/8ebea8a23178.tif: 9 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/910b93e1cf28.tif: 9 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/92450a58e849.tif: 12 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/932c4fa02fee.tif: 18 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/94dd41f92b1d.tif: 6 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/99ddcf7fb9a3.tif: 4 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/9a4ac92edd79.tif: 12 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/9a4d59b6c3ec.tif: 17 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/a0fed17a5bc6.tif: 4 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/a12848a1b5f9.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/a27ffddbba42.tif: 3 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/a661cbfc8464.tif: 10 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/aa05d1efb6bc.tif: 6 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/ace43628b108.tif: 14 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/adadaeaa3635.tif: 11 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/b04db3efff0a.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/b29ab50ca7aa.tif: 6 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/b987af6e6106.tif: 2 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/ba5cffc61dce.tif: 8 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/be0d76907fd8.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/bf0f8e9bf257.tif: 9 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/bffe164b7f65.tif: 6 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/c2731b6c0c17.tif: 9 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/c3e34170ff28.tif: 7 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/c738789588f9.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/cc103e610139.tif: 12 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/cc8bdabbc3eb.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/d0d0fda7789f.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/d17335683f96.tif: 4 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/d4a6a9e8d85e.tif: 8 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/d6bd77533b2b.tif: 8 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/d82695d80caf.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/d873758275c6.tif: 12 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/d9547a630fab.tif: 8 duplicate labels removed
# train: New cache created: /content/dataset/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/dataset/val/labels... 245 images, 0 backgrounds, 0 corrupt: 100%|██████████| 245/245 [00:00<00:00, 339.42it/s]
# val: WARNING ⚠️ /content/dataset/val/images/da9507215057.tif: 8 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/dbf5ec194977.tif: 7 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/dc0b64e2a3a6.tif: 12 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/e52522470fea.tif: 4 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/e9c9c5fb7aef.tif: 1 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/ef39b81a7917.tif: 1 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/f217dcd37517.tif: 10 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/f53f64d220e3.tif: 3 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/f9faf12fc07b.tif: 4 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/fa10ae8f9fec.tif: 7 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/fa6a66f01888.tif: 11 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/fbe845f13c20.tif: 8 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/fce9ad75428d.tif: 9 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/ffd3d193c71e.tif: 2 duplicate labels removed
# val: New cache created: /content/dataset/val/labels.cache
# Plotting labels to HuBMAP/yolov8x-seg/labels.jpg...
# optimizer: SGD(lr=0.01, momentum=0.947) with parameter groups 106 weight(decay=0.0), 117 weight(decay=0.0005), 116 bias(decay=0.0)
# Image sizes 512 train, 512 val
# Using 4 dataloader workers
# Logging results to HuBMAP/yolov8x-seg
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        1/50
00:00,  1.03s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:07<00:00,  1.02it/s]
#                    all        245       2370      0.556      0.551      0.548      0.371      0.561      0.556      0.555      0.369
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       29/50        10G      1.375      1.786      1.055      1.091        157        512: 100%|██████████| 87/87 [01:29<00:00,  1.03s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:15<00:00,  1.95s/it]
#                    all        245       2370      0.572      0.558      0.542      0.381      0.574      0.562      0.544       0.37
# Stopping training early as no improvement observed in last 6 epochs. Best results observed at epoch 23, best model saved as best.pt.
# To update EarlyStopping(patience=6) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 29 epochs completed in 0.816 hours.
# Optimizer stripped from HuBMAP/yolov8x-seg/weights/last.pt, 143.9MB
# Optimizer stripped from HuBMAP/yolov8x-seg/weights/best.pt, 143.9MB
#
# Validating HuBMAP/yolov8x-seg/weights/best.pt...
# Ultralytics YOLOv8.0.135 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8x-seg summary (fused): 295 layers, 71723545 parameters, 0 gradients
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:16<00:00,  2.04s/it]
#                    all        245       2370      0.579      0.533      0.554      0.388      0.581      0.535      0.559      0.381
#           blood_vessel        245       2159      0.591      0.639      0.622      0.309      0.598      0.646      0.633      0.292
#             glomerulus        245         73      0.843      0.836      0.909      0.782      0.843      0.836       0.91      0.787
#                 unsure        245        138      0.303      0.123      0.133     0.0722      0.303      0.123      0.134     0.0645
# Speed: 0.6ms preprocess, 21.4ms inference, 0.0ms loss, 3.4ms postprocess per image
# Results saved to HuBMAP/yolov8x-seg

# %%
files.download('/content/HuBMAP/yolov8x-seg/weights/best.pt')

# %%
import matplotlib.pyplot as plt
from PIL import Image

# %%
dirlist = os.listdir("/content/dataset/val/images")
print(dirlist[:5])
# Out:
# ['f45a29109ff5.tif', 'e868c30b2af7.tif', 'eaa85fa2b857.tif', 'db20b95a3ab9.tif', 'da3180fa5201.tif']

# %%
model = YOLO("/content/HuBMAP/yolov8x-seg/weights/best.pt")
history = model.predict("/content/dataset/val/images/fbd64e93f84d.tif")[0]
image = history.plot()
plt.imshow(image)
plt.show()
# Out:
# image 1/1 /content/dataset/val/images/fbd64e93f84d.tif: 512x512 6 blood_vessels, 66.7ms
# Speed: 1.5ms preprocess, 66.7ms inference, 6.8ms postprocess per image at shape (1, 3, 512, 512)

# %%
F1_curve = Image.open("/content/HuBMAP/yolov8x-seg/results.png")
plt.figure(figsize=(15,20))
plt.imshow(F1_curve)
plt.show()

# %%
results = pd.read_csv("/content/HuBMAP/yolov8x-seg/results.csv")
results.head()
results.to_csv('/gdrive/MyDrive/DATA/HuBMAP/Results/is_yolov8_v6_20230715.csv')

# %%
results
# Out:
#                      epoch           train/box_loss           train/seg_loss  \
# 0                        0                   1.9995                   3.2134
# 1                        1                   1.5502                   2.1360
# 2                        2                   1.5232                   2.0343
# 3                        3                   1.5553                   2.0230
# 4                        4                   1.5675                   2.0543
# 5                        5                   1.5728                   2.0490
# 6                        6                   1.5557                   2.0150
# 7                        7                   1.5361                   1.9779
# 8                        8                   1.5221                   1.9643
#
#             train/cls_loss           train/dfl_loss     metrics/precision(B)  \
# 0                   2.8495                   1.5534                  0.49513
# 1                   1.7523                   1.2139                  0.52192
# 2                   1.5652                   1.1844                  0.58208
# 3                   1.4277                   1.1864                  0.48756
# 4                   1.3993                   1.1806                  0.54190
# 5                   1.3440                   1.1895                  0.64087
# 6                   1.3435                   1.1852                  0.64434
# 7                   1.2967                   1.1682                  0.57342
# 8                   1.2670                   1.1679                  0.60959
#
#          metrics/recall(B)         metrics/mAP50(B)      metrics/mAP50-95(B)  \
# 0                  0.31126                  0.30362                  0.21525
# 1                  0.49569                  0.45836                  0.32593
# 2                  0.49147                  0.51910                  0.36601
# 3                  0.52277                  0.49420                  0.33485
# 4                  0.51518                  0.48753                  0.32797
# 5                  0.49362                  0.50402                  0.35034
# 6                  0.45196                  0.49503                  0.33728
# 7                  0.52276                  0.52530                  0.35288
# 8                  0.48081                  0.50265                  0.34716
#
#       metrics/precision(M)        metrics/recall(M)         metrics/mAP50(M)  \
# 0                  0.48846                  0.31383                  0.30144
# 1                  0.52175                  0.49551                  0.45812
# 2                  0.57762                  0.50170                  0.52841
# 3                  0.49112                  0.52977                  0.50207
# 4                  0.53600                  0.50569                  0.47557
# 5                  0.64294                  0.49643                  0.50992
# 6                  0.64426                  0.45187                  0.49244
# 7                  0.57880                  0.52800                  0.53762
# 8                  0.61213                  0.48223                  0.50306
#
#        metrics/mAP50-95(M)             val/box_loss             val/seg_loss  \
# 0                  0.20406                   1.6169                   2.4874
# 1                  0.31119                   1.5267                   2.1838
# 2                  0.36030                   1.5957                   2.1397
# 3                  0.33773                   1.6220                   2.2084
# 4                  0.31015                   1.6225                   2.6393
# 5                  0.34529                   1.5873                   2.2300
# 6                  0.32671                   1.6519                   2.5492
# 7                  0.34573                   1.5920                   2.1253
# 8                  0.33117                   1.6090                   2.4518
#
#               val/cls_loss             val/dfl_loss                   lr/pg0  \
# 0                   1.8744                   1.2809                 0.070390
# 1                   1.6209                   1.2072                 0.040257
# 2                   1.3652                   1.2397                 0.009992
# 3                   1.4707                   1.2646                 0.009401
# 4                   1.4731                   1.2712                 0.009401
# 5                   1.3814                   1.2373                 0.009201
# 6                   1.7756                   1.2730                 0.009001
# 7                   1.4139                   1.2533                 0.008801
# 8                   1.5331                   1.2657                 0.008601
#
#                     lr/pg1                   lr/pg2
# 0                 0.003290                 0.003290
# 1                 0.006491                 0.006491
# 2                 0.009559                 0.009559
# 3                 0.009401                 0.009401
# 4                 0.009401                 0.009401
# 5                 0.009201                 0.009201
# 6                 0.009001                 0.009001
# 7                 0.008801                 0.008801
# 8                 0.008601                 0.008601

# %%
plt.figure

# %%
plt.figure(figsize=(15,20))
confusion_matrix = Image.open("/content/HuBMAP/yolov8x-seg/confusion_matrix.png")
plt.imshow(confusion_matrix)
plt.show()

# %%
plt.figure(figsize=(15,20))
confusion_matrix = Image.open("/content/HuBMAP/yolov8x-seg/confusion_matrix_normalized.png")
plt.imshow(confusion_matrix)
plt.show()

# %%
results = pd.read_csv("/gdrive/MyDrive/DATA/HuBMAP/Results/is_yolov8_v6_20230715.csv",index_col=0)
results.columns = results.columns.str.strip()

results
# Out:
#     epoch  train/box_loss  train/seg_loss  train/cls_loss  train/dfl_loss  \
# 0       0          2.0146          3.0812          2.7086          1.5177
# 1       1          1.6398          2.2424          1.7666          1.2443
# 2       2          1.6595          2.2304          1.6429          1.2271
# 3       3          1.6822          2.2355          1.6027          1.2284
# 4       4          1.6862          2.2433          1.5375          1.2368
# 5       5          1.6700          2.2170          1.5152          1.2448
# 6       6          1.6622          2.2010          1.4722          1.2181
# 7       7          1.6456          2.1732          1.4456          1.2262
# 8       8          1.6274          2.1305          1.4410          1.2144
# 9       9          1.6213          2.1124          1.3903          1.2046
# 10     10          1.5899          2.0829          1.4016          1.1994
# 11     11          1.5866          2.0575          1.3577          1.1968
# 12     12          1.5586          2.0139          1.3127          1.1802
# 13     13          1.5634          2.0255          1.3234          1.1840
# 14     14          1.5484          2.0262          1.3111          1.1749
# 15     15          1.5296          1.9712          1.2774          1.1738
# 16     16          1.5410          1.9805          1.2804          1.1759
# 17     17          1.4991          1.9618          1.2383          1.1596
# 18     18          1.5032          1.9482          1.2248          1.1471
# 19     19          1.4893          1.9329          1.2222          1.1431
# 20     20          1.4705          1.9014          1.2115          1.1313
# 21     21          1.4597          1.9060          1.1746          1.1344
# 22     22          1.4561          1.8772          1.1490          1.1264
# 23     23          1.4396          1.8720          1.1430          1.1242
# 24     24          1.4414          1.8752          1.1393          1.1191
# 25     25          1.4112          1.8378          1.1094          1.1081
# 26     26          1.4089          1.8354          1.1032          1.1118
# 27     27          1.3872          1.8138          1.0823          1.1018
# 28     28          1.3754          1.7857          1.0547          1.0907
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0                0.38440            0.31267           0.32919
# 1                0.45573            0.44115           0.41473
# 2                0.26633            0.40538           0.29242
# 3                0.33188            0.36087           0.28365
# 4                0.73517            0.34097           0.35205
# 5                0.50433            0.42623           0.42442
# 6                0.50917            0.44764           0.44466
# 7                0.42142            0.45926           0.44396
# 8                0.39101            0.53801           0.47726
# 9                0.44329            0.41880           0.38988
# 10               0.77349            0.45873           0.47216
# 11               0.45476            0.44308           0.40918
# 12               0.54446            0.52424           0.50360
# 13               0.50411            0.53106           0.50665
# 14               0.54049            0.55762           0.54851
# 15               0.50439            0.50972           0.53697
# 16               0.45177            0.55782           0.47120
# 17               0.52379            0.50644           0.49821
# 18               0.50719            0.49635           0.48736
# 19               0.56616            0.45962           0.49473
# 20               0.53991            0.56309           0.54341
# 21               0.57962            0.57174           0.54820
# 22               0.57920            0.53266           0.55434
# 23               0.53398            0.56511           0.54523
# 24               0.57229            0.56370           0.55091
# 25               0.53584            0.54930           0.52138
# 26               0.54062            0.55777           0.54809
# 27               0.55581            0.55104           0.54825
# 28               0.57203            0.55824           0.54174
#
#     metrics/mAP50-95(B)  metrics/precision(M)  metrics/recall(M)  \
# 0               0.22630               0.38969            0.31334
# 1               0.27858               0.46272            0.44779
# 2               0.18032               0.25725            0.39488
# 3               0.18304               0.35578            0.34953
# 4               0.23986               0.74023            0.34375
# 5               0.28631               0.47988            0.43236
# 6               0.30434               0.51264            0.45042
# 7               0.30199               0.41817            0.45571
# 8               0.32433               0.41062            0.52576
# 9               0.26479               0.45002            0.42776
# 10              0.32424               0.78264            0.44394
# 11              0.27670               0.47033            0.45258
# 12              0.33927               0.54176            0.51973
# 13              0.33720               0.50376            0.52588
# 14              0.37606               0.54423            0.55830
# 15              0.36700               0.51427            0.52117
# 16              0.31943               0.44858            0.54986
# 17              0.34324               0.53281            0.51035
# 18              0.32837               0.50511            0.49611
# 19              0.33562               0.56921            0.46240
# 20              0.37865               0.54209            0.56541
# 21              0.37886               0.57960            0.57025
# 22              0.38770               0.58258            0.53480
# 23              0.37855               0.56940            0.54583
# 24              0.38913               0.57649            0.57073
# 25              0.36563               0.53539            0.54966
# 26              0.38009               0.54423            0.56178
# 27              0.37086               0.56092            0.55580
# 28              0.38080               0.57412            0.56153
#
#     metrics/mAP50(M)  metrics/mAP50-95(M)  val/box_loss  val/seg_loss  \
# 0            0.32872              0.21648        1.7006        2.4837
# 1            0.42085              0.27323        1.7936        2.3586
# 2            0.28170              0.16340        1.8207        2.9753
# 3            0.28374              0.18034        1.8930        2.7486
# 4            0.35287              0.22851        1.8761        2.9738
# 5            0.42217              0.26309        1.7829        2.7089
# 6            0.44889              0.29933        1.8025        2.5631
# 7            0.43634              0.29021        1.7603        2.5477
# 8            0.47793              0.31872        1.6954        2.4393
# 9            0.39663              0.26966        1.9567        2.5189
# 10           0.47524              0.30949        1.7049        2.4350
# 11           0.42650              0.28337        2.0116        2.5068
# 12           0.50646              0.34198        1.6700        2.2031
# 13           0.50755              0.33059        1.6744        2.3882
# 14           0.54865              0.36729        1.6611        2.3246
# 15           0.54769              0.36777        1.6515        2.2378
# 16           0.47364              0.31126        1.7318        2.5912
# 17           0.50690              0.33339        1.7068        2.3802
# 18           0.49428              0.31956        1.7036        2.3783
# 19           0.50076              0.33349        1.6998        2.2261
# 20           0.54654              0.37101        1.6402        2.2423
# 21           0.55124              0.36945        1.6443        2.2444
# 22           0.55900              0.38252        1.6211        2.2210
# 23           0.54715              0.37717        1.6358        2.1546
# 24           0.55618              0.38015        1.6343        2.1570
# 25           0.52644              0.35865        1.6455        2.4367
# 26           0.54711              0.37630        1.6472        2.1850
# 27           0.55512              0.36911        1.6416        2.1789
# 28           0.54411              0.37041        1.6596        2.2112
#
#     val/cls_loss  val/dfl_loss    lr/pg0    lr/pg1    lr/pg2
# 0         1.9792        1.3361  0.070345  0.003295  0.003295
# 1         1.8330        1.3649  0.040212  0.006496  0.006496
# 2         1.7866        1.3437  0.009947  0.009564  0.009564
# 3         2.0298        1.4137  0.009401  0.009401  0.009401
# 4         2.7741        1.4238  0.009401  0.009401  0.009401
# 5         1.7376        1.3445  0.009201  0.009201  0.009201
# 6         1.7960        1.3514  0.009001  0.009001  0.009001
# 7         1.6211        1.3087  0.008801  0.008801  0.008801
# 8         1.6695        1.3006  0.008601  0.008601  0.008601
# 9         1.7572        1.4330  0.008402  0.008402  0.008402
# 10        1.8907        1.3150  0.008202  0.008202  0.008202
# 11        1.8731        1.4632  0.008002  0.008002  0.008002
# 12        1.4339        1.2805  0.007802  0.007802  0.007802
# 13        1.4515        1.2883  0.007602  0.007602  0.007602
# 14        1.3538        1.2732  0.007403  0.007403  0.007403
# 15        1.3783        1.2834  0.007203  0.007203  0.007203
# 16        1.6491        1.3182  0.007003  0.007003  0.007003
# 17        1.4533        1.2999  0.006803  0.006803  0.006803
# 18        1.4426        1.3023  0.006603  0.006603  0.006603
# 19        1.4379        1.3143  0.006404  0.006404  0.006404
# 20        1.3058        1.2592  0.006204  0.006204  0.006204
# 21        1.2936        1.2709  0.006004  0.006004  0.006004
# 22        1.2903        1.2511  0.005804  0.005804  0.005804
# 23        1.3171        1.2593  0.005604  0.005604  0.005604
# 24        1.2954        1.2661  0.005405  0.005405  0.005405
# 25        1.3921        1.2799  0.005205  0.005205  0.005205
# 26        1.2912        1.2716  0.005005  0.005005  0.005005
# 27        1.2791        1.2828  0.004805  0.004805  0.004805
# 28        1.3149        1.2815  0.004605  0.004605  0.004605

# %%
plt.figure(figsize=(15,15))

loss_labels = results.columns.tolist()[1:5] + results.columns.tolist()[13:17]
for idx in range(4):
  plt.subplot(2,2,idx+1)
  plt.plot(results['epoch'],results[loss_labels[idx]],label = loss_labels[idx])
  plt.plot(results['epoch'],results[loss_labels[idx+4]],label = loss_labels[idx+4])
  plt.legend(loc='upper right')
  plt.xlabel('epoch')
  plt.ylabel(loss_labels[idx].split('/')[1])
  plt.title(loss_labels[idx].split('/')[1])



plt.show();

# %%
results
# Out:
#     epoch  train/box_loss  train/seg_loss  train/cls_loss  train/dfl_loss  \
# 0       0          2.0146          3.0812          2.7086          1.5177
# 1       1          1.6398          2.2424          1.7666          1.2443
# 2       2          1.6595          2.2304          1.6429          1.2271
# 3       3          1.6822          2.2355          1.6027          1.2284
# 4       4          1.6862          2.2433          1.5375          1.2368
# 5       5          1.6700          2.2170          1.5152          1.2448
# 6       6          1.6622          2.2010          1.4722          1.2181
# 7       7          1.6456          2.1732          1.4456          1.2262
# 8       8          1.6274          2.1305          1.4410          1.2144
# 9       9          1.6213          2.1124          1.3903          1.2046
# 10     10          1.5899          2.0829          1.4016          1.1994
# 11     11          1.5866          2.0575          1.3577          1.1968
# 12     12          1.5586          2.0139          1.3127          1.1802
# 13     13          1.5634          2.0255          1.3234          1.1840
# 14     14          1.5484          2.0262          1.3111          1.1749
# 15     15          1.5296          1.9712          1.2774          1.1738
# 16     16          1.5410          1.9805          1.2804          1.1759
# 17     17          1.4991          1.9618          1.2383          1.1596
# 18     18          1.5032          1.9482          1.2248          1.1471
# 19     19          1.4893          1.9329          1.2222          1.1431
# 20     20          1.4705          1.9014          1.2115          1.1313
# 21     21          1.4597          1.9060          1.1746          1.1344
# 22     22          1.4561          1.8772          1.1490          1.1264
# 23     23          1.4396          1.8720          1.1430          1.1242
# 24     24          1.4414          1.8752          1.1393          1.1191
# 25     25          1.4112          1.8378          1.1094          1.1081
# 26     26          1.4089          1.8354          1.1032          1.1118
# 27     27          1.3872          1.8138          1.0823          1.1018
# 28     28          1.3754          1.7857          1.0547          1.0907
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0                0.38440            0.31267           0.32919
# 1                0.45573            0.44115           0.41473
# 2                0.26633            0.40538           0.29242
# 3                0.33188            0.36087           0.28365
# 4                0.73517            0.34097           0.35205
# 5                0.50433            0.42623           0.42442
# 6                0.50917            0.44764           0.44466
# 7                0.42142            0.45926           0.44396
# 8                0.39101            0.53801           0.47726
# 9                0.44329            0.41880           0.38988
# 10               0.77349            0.45873           0.47216
# 11               0.45476            0.44308           0.40918
# 12               0.54446            0.52424           0.50360
# 13               0.50411            0.53106           0.50665
# 14               0.54049            0.55762           0.54851
# 15               0.50439            0.50972           0.53697
# 16               0.45177            0.55782           0.47120
# 17               0.52379            0.50644           0.49821
# 18               0.50719            0.49635           0.48736
# 19               0.56616            0.45962           0.49473
# 20               0.53991            0.56309           0.54341
# 21               0.57962            0.57174           0.54820
# 22               0.57920            0.53266           0.55434
# 23               0.53398            0.56511           0.54523
# 24               0.57229            0.56370           0.55091
# 25               0.53584            0.54930           0.52138
# 26               0.54062            0.55777           0.54809
# 27               0.55581            0.55104           0.54825
# 28               0.57203            0.55824           0.54174
#
#     metrics/mAP50-95(B)  metrics/precision(M)  metrics/recall(M)  \
# 0               0.22630               0.38969            0.31334
# 1               0.27858               0.46272            0.44779
# 2               0.18032               0.25725            0.39488
# 3               0.18304               0.35578            0.34953
# 4               0.23986               0.74023            0.34375
# 5               0.28631               0.47988            0.43236
# 6               0.30434               0.51264            0.45042
# 7               0.30199               0.41817            0.45571
# 8               0.32433               0.41062            0.52576
# 9               0.26479               0.45002            0.42776
# 10              0.32424               0.78264            0.44394
# 11              0.27670               0.47033            0.45258
# 12              0.33927               0.54176            0.51973
# 13              0.33720               0.50376            0.52588
# 14              0.37606               0.54423            0.55830
# 15              0.36700               0.51427            0.52117
# 16              0.31943               0.44858            0.54986
# 17              0.34324               0.53281            0.51035
# 18              0.32837               0.50511            0.49611
# 19              0.33562               0.56921            0.46240
# 20              0.37865               0.54209            0.56541
# 21              0.37886               0.57960            0.57025
# 22              0.38770               0.58258            0.53480
# 23              0.37855               0.56940            0.54583
# 24              0.38913               0.57649            0.57073
# 25              0.36563               0.53539            0.54966
# 26              0.38009               0.54423            0.56178
# 27              0.37086               0.56092            0.55580
# 28              0.38080               0.57412            0.56153
#
#     metrics/mAP50(M)  metrics/mAP50-95(M)  val/box_loss  val/seg_loss  \
# 0            0.32872              0.21648        1.7006        2.4837
# 1            0.42085              0.27323        1.7936        2.3586
# 2            0.28170              0.16340        1.8207        2.9753
