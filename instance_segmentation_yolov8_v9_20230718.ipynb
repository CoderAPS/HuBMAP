# %% [markdown]
# <a href="https://colab.research.google.com/github/CoderAPS/HuBMAP/blob/main/instance_segmentation_yolov8_v9_20230718.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Medical Instance Segmentation with YOLOv8 version 9
# References:<br>
# https://docs.ultralytics.com/usage/cfg/#tasks <br>
# how YOLO v8 works: https://openmmlab.medium.com/dive-into-yolov8-how-does-this-state-of-the-art-model-work-10f18f74bab1 <br>
#
# about COCO dataset and format:<br>
# https://towardsdatascience.com/master-the-coco-dataset-for-semantic-image-segmentation-part-1-of-2-732712631047

# %% [markdown]
# Run 1: <br>
# Split: 0.8 & 0.2, LR0 = 0.01, LRf = 0.001, batch = 16, droupout = 0.5, patience = 6, epoch = 60 (early stopping at epoch 18),   data = /gdrive/MyDrive/DATA/HuBMAP/images

# %%
# Mount google drive
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# !ls /gdrive/MyDrive/DATA/HuBMAP/
# Out:
# annotation_info.csv  masks_white_bkgrnd  sample_submission.csv	train_list.csv
# blue_images	     norm_images	 test			val_list.csv
# images		     polygons.jsonl	 test2			wsi_meta.csv
# images_info.csv      red_images		 test_list.csv
# masks		     Results		 tile_meta.csv

# %%
# !ls /content
# Out:
# sample_data

# %%
# !pip install colorama
# Out:
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama
# Successfully installed colorama-0.4.6

# %%
# libraries needed to create the create the dataset in COCO format
from itertools import chain
import json
import os
import glob
import shutil
from tqdm.notebook import tqdm
from colorama import Fore
import yaml
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from PIL import Image
import cv2

# use this code to clear output
from IPython import display
from google.colab import files
#display.clear_output()

# %%
#@title modified COCO dataset
# class for creating the dataset
class COCODataset_mod:
    def __init__(self, images_dirpath: str,
                 annotations_filepath: str,
                 length: int = 1633):
        self.train_size = None
        self.val_size = None
        self.length = length
        self.classes = None
        self.labels_counter = None
        self.normalize = None

        self.images_dirpath = images_dirpath

        self.annotations_filepath = annotations_filepath
        self.modified_dirpath = os.path.join(os.getcwd(),"modified")
        self.dataset_dirpath = os.path.join(os.getcwd(), "dataset")
        self.train_dirpath =  os.path.join(self.dataset_dirpath, "train")
        self.val_dirpath =  os.path.join(self.dataset_dirpath, "val")
        self.config_path = os.path.join(self.dataset_dirpath, "coco.yaml")

        self.samples = self.parse_jsonl(annotations_filepath)
        self.classes_dict = {
            "blood_vessel": 0,
            "glomerulus": 1,
            "unsure": 2,
        }

    def __prepare_dirs(self) -> None:
        if not os.path.exists(self.dataset_dirpath):
            os.makedirs(os.path.join(self.modified_dirpath), exist_ok=True)
            os.makedirs(os.path.join(self.train_dirpath, "images"), exist_ok=True)
            os.makedirs(os.path.join(self.train_dirpath, "labels"), exist_ok=True)
            os.makedirs(os.path.join(self.val_dirpath, "images"), exist_ok=True)
            os.makedirs(os.path.join(self.val_dirpath, "labels"), exist_ok=True)
        else:
            raise RuntimeError("Dataset already exists!")

    def __define_splitratio(self) -> None:
        self.train_size = round(self.length * self.train_size)
        self.val_size = self.length - self.train_size
        assert self.train_size + self.val_size == self.length

    def parse_jsonl(self, path: str) -> list[dict, ...]:
        with open(path, 'r') as json_file:
            jsonl_samples = [
                json.loads(line)
                for line in tqdm(
                    json_file, desc="Processing polygons", total=self.length
                )
            ]
        return jsonl_samples

    def __define_paths(self, i: int) -> dict:
        data_path = self.val_dirpath
        if i < self.train_size:
            data_path = self.train_dirpath
        return {
            "images": os.path.join(data_path, "images"),
            "labels": os.path.join(data_path, "labels")
        }

    @staticmethod
    def __get_label_path(paths_dict: dict, identifier: str) -> str:
        return os.path.join(
            paths_dict["labels"],
            f"{identifier}.txt"
        )

    @staticmethod
    def __get_image_path(paths_dict: dict, identifier: str) -> str:
        return os.path.join(
            paths_dict["images"],
            f"{identifier}.tif"
        )

    def __modify_image(self, image_path: str, identifier: str) -> str:
      image = cv2.imread(image_path)
      image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

      cv2.imwrite(self.modified_dirpath + identifier + '.tif',image)
      return self.modified_dirpath + identifier + '.tif'

    def __modify_label(self, label_path: str, identifier: str) -> str:
      with open(label_path, 'r') as file:
          lines = file.readlines()


    def __copy_image(self, dst_path: str, identifier: str) -> str:

        # make temporay directory under under cwd and call it modified
        image_path = os.path.join(self.images_dirpath, f"{identifier}.tif")
        modified_image_path = self.__modify_image(image_path, identifier)

        shutil.copyfile(modified_image_path, dst_path)

        return dst_path


    def __copy_label(self, annotations: list, dst_path: str) -> None:
        with open(dst_path, "w") as file:
            for annotation in annotations:
                coordinates = annotation["coordinates"][0]
                label = self.classes_dict[annotation["type"]]
                if label in self.classes:
                    if coordinates:
                        if self.normalize:
                            coordinates = np.array(coordinates) / 512.0
                        coordinates = " ".join(map(str, chain(*coordinates)))
                        file.write(f"{label} {coordinates}\n")
                        self.labels_counter += 1

    def __splitfolders(self):
        for i, line in tqdm(
                enumerate(self.samples),
                desc="Dataset creation", total=self.length
        ):
            self.labels_counter = 0
            identifier = line["id"]
            annotations = line["annotations"]
            paths_dict = self.__define_paths(i)

            dst_image_path = self.__get_image_path(paths_dict, identifier)
            dst_label_path = self.__get_label_path(paths_dict, identifier)

            self.__copy_image(dst_image_path, identifier)
            self.__copy_label(annotations, dst_label_path)

            if self.labels_counter == 0:
                os.remove(dst_image_path)
                os.remove(dst_label_path)

    def __count_dataset(self) -> dict:
        train_images = len(os.listdir(os.path.join(self.train_dirpath, "images")))
        train_labels = len(os.listdir(os.path.join(self.train_dirpath, "labels")))
        val_images = len(os.listdir(os.path.join(self.val_dirpath, "images")))
        val_labels = len(os.listdir(os.path.join(self.val_dirpath, "labels")))
        return {
            "train_images": train_images,
            "train_labels": train_labels,
            "val_images": val_images,
            "val_labels": val_labels
        }

    @staticmethod
    def __check_sanity(count_dict: dict) -> None:
        assert count_dict["train_images"] == count_dict["train_labels"]
        assert count_dict["val_images"] == count_dict["val_labels"]

    def __finalizing(self, count_dict: dict) -> None:
        assert os.path.exists(self.dataset_dirpath)

        example_structure = [
            "dataset",
            "train", "labels", "images",
            "val", "labels", "images"
        ]

        dir_bone = (
            dirname.split("/")[-1]
            for dirname, _, filenames in os.walk(self.dataset_dirpath)
            if dirname.split("/")[-1] in example_structure
        )

        try:
            print("\n~ HuBMAP Dataset Structure ~\n")
            print(
            f"""
          ├── {next(dir_bone)}
          │   │
          │   ├── {next(dir_bone)}
          │   │   └── {next(dir_bone)}
          │   │   └── {next(dir_bone)}
          │   │
          │   ├── {next(dir_bone)}
          │   │   └── {next(dir_bone)}
          │   │   └── {next(dir_bone)}
            """
            )
        except StopIteration as e:
            print(e)
        else:
            print(Fore.GREEN + "-> Success")
            print(Fore.GREEN + f"Train dataset: {count_dict['train_images']}\nVal dataset: {count_dict['val_images']}")

    def get_config(self) ->dict:
        names = ["blood_vessel", "glomerulus", "unsure"]
        return {
            "train": str(self.train_dirpath),
            "val": str(self.val_dirpath),
            "names": [names[i] for i in self.classes]
        }

    @staticmethod
    def display_config(config: dict) -> None:
        print(Fore.BLACK + "\n~ HuBMAP Config Structure ~\n")
        print(
        f"""
      │   │
      │   ├── train
      │   │   └── {config['train']}/images
      │   │
      │   │
      │   ├── val
      │   │   └── {config['val']}/images
      │   │
      │   │
      │   ├── names
      │   │   └── {' '.join(config['names'])}
        """
        )
        print(Fore.GREEN + "-> Success")
        print(Fore.GREEN + f"Number of classes: {len(config['names'])}"
                           f"\nClasses: {' '.join(config['names'])}"
              )

    def write_config(self, config: dict) -> None:
        with open(self.config_path, mode="w") as f:
            yaml.safe_dump(stream=f, data=config)

    def __call__(self, train_size: float,
                 classes: list[int, ...],
                 make_config: bool = True,
                 normalize: bool = True
                ) -> None:

        self.train_size = train_size
        self.classes = classes
        self.normalize = normalize

        self.__define_splitratio()
        self.__prepare_dirs()
        self.__splitfolders()
        count_dict = self.__count_dataset()
        self.__check_sanity(count_dict)
        self.__finalizing(count_dict)

        if make_config:
            config = self.get_config()
            self.write_config(config)
            self.display_config(config)

# %%
# class for creating the dataset
class COCODataset:
    def __init__(self, images_dirpath: str, annotations_filepath: str, length: int = 1633):
        self.train_size = None
        self.val_size = None
        self.length = length
        self.classes = None
        self.labels_counter = None
        self.normalize = None

        self.images_dirpath = images_dirpath
        self.annotations_filepath = annotations_filepath
        self.dataset_dirpath = os.path.join(os.getcwd(), "dataset")
        self.train_dirpath =  os.path.join(self.dataset_dirpath, "train")
        self.val_dirpath =  os.path.join(self.dataset_dirpath, "val")
        self.config_path = os.path.join(self.dataset_dirpath, "coco.yaml")

        self.samples = self.parse_jsonl(annotations_filepath)
        self.classes_dict = {
            "blood_vessel": 0,
            "glomerulus": 1,
            "unsure": 2,
        }

    def __prepare_dirs(self) -> None:
        if not os.path.exists(self.dataset_dirpath):
            os.makedirs(os.path.join(self.train_dirpath, "images"), exist_ok=True)
            os.makedirs(os.path.join(self.train_dirpath, "labels"), exist_ok=True)
            os.makedirs(os.path.join(self.val_dirpath, "images"), exist_ok=True)
            os.makedirs(os.path.join(self.val_dirpath, "labels"), exist_ok=True)
        else:
            raise RuntimeError("Dataset already exists!")

    def __define_splitratio(self) -> None:
        self.train_size = round(self.length * self.train_size)
        self.val_size = self.length - self.train_size
        assert self.train_size + self.val_size == self.length

    def parse_jsonl(self, path: str) -> list[dict, ...]:
        with open(path, 'r') as json_file:
            jsonl_samples = [
                json.loads(line)
                for line in tqdm(
                    json_file, desc="Processing polygons", total=self.length
                )
            ]
        return jsonl_samples

    def __define_paths(self, i: int) -> dict:
        data_path = self.val_dirpath
        if i < self.train_size:
            data_path = self.train_dirpath
        return {
            "images": os.path.join(data_path, "images"),
            "labels": os.path.join(data_path, "labels")
        }

    @staticmethod
    def __get_label_path(paths_dict: dict, identifier: str) -> str:
        return os.path.join(
            paths_dict["labels"],
            f"{identifier}.txt"
        )

    @staticmethod
    def __get_image_path(paths_dict: dict, identifier: str) -> str:
        return os.path.join(
            paths_dict["images"],
            f"{identifier}.tif"
        )

    def __copy_image(self, dst_path: str, identifier: str) -> str:
        shutil.copyfile(
            os.path.join(self.images_dirpath, f"{identifier}.tif"),
            dst_path
        )

    def __copy_label(self, annotations: list, dst_path: str) -> None:
        with open(dst_path, "w") as file:
            for annotation in annotations:
                coordinates = annotation["coordinates"][0]
                label = self.classes_dict[annotation["type"]]
                if label in self.classes:
                    if coordinates:
                        if self.normalize:
                            coordinates = np.array(coordinates) / 512.0
                        coordinates = " ".join(map(str, chain(*coordinates)))
                        file.write(f"{label} {coordinates}\n")
                        self.labels_counter += 1

    def __splitfolders(self):
        for i, line in tqdm(
                enumerate(self.samples),
                desc="Dataset creation", total=self.length
        ):
            self.labels_counter = 0
            identifier = line["id"]
            annotations = line["annotations"]
            paths_dict = self.__define_paths(i)

            dst_image_path = self.__get_image_path(paths_dict, identifier)
            dst_label_path = self.__get_label_path(paths_dict, identifier)

            self.__copy_image(dst_image_path, identifier)
            self.__copy_label(annotations, dst_label_path)

            if self.labels_counter == 0:
                os.remove(dst_image_path)
                os.remove(dst_label_path)

    def __count_dataset(self) -> dict:
        train_images = len(os.listdir(os.path.join(self.train_dirpath, "images")))
        train_labels = len(os.listdir(os.path.join(self.train_dirpath, "labels")))
        val_images = len(os.listdir(os.path.join(self.val_dirpath, "images")))
        val_labels = len(os.listdir(os.path.join(self.val_dirpath, "labels")))
        return {
            "train_images": train_images,
            "train_labels": train_labels,
            "val_images": val_images,
            "val_labels": val_labels
        }

    @staticmethod
    def __check_sanity(count_dict: dict) -> None:
        assert count_dict["train_images"] == count_dict["train_labels"]
        assert count_dict["val_images"] == count_dict["val_labels"]

    def __finalizing(self, count_dict: dict) -> None:
        assert os.path.exists(self.dataset_dirpath)

        example_structure = [
            "dataset",
            "train", "labels", "images",
            "val", "labels", "images"
        ]

        dir_bone = (
            dirname.split("/")[-1]
            for dirname, _, filenames in os.walk(self.dataset_dirpath)
            if dirname.split("/")[-1] in example_structure
        )

        try:
            print("\n~ HuBMAP Dataset Structure ~\n")
            print(
            f"""
          ├── {next(dir_bone)}
          │   │
          │   ├── {next(dir_bone)}
          │   │   └── {next(dir_bone)}
          │   │   └── {next(dir_bone)}
          │   │
          │   ├── {next(dir_bone)}
          │   │   └── {next(dir_bone)}
          │   │   └── {next(dir_bone)}
            """
            )
        except StopIteration as e:
            print(e)
        else:
            print(Fore.GREEN + "-> Success")
            print(Fore.GREEN + f"Train dataset: {count_dict['train_images']}\nVal dataset: {count_dict['val_images']}")

    def get_config(self) ->dict:
        names = ["blood_vessel", "glomerulus", "unsure"]
        return {
            "train": str(self.train_dirpath),
            "val": str(self.val_dirpath),
            "names": [names[i] for i in self.classes]
        }

    @staticmethod
    def display_config(config: dict) -> None:
        print(Fore.BLACK + "\n~ HuBMAP Config Structure ~\n")
        print(
        f"""
      │   │
      │   ├── train
      │   │   └── {config['train']}/images
      │   │
      │   │
      │   ├── val
      │   │   └── {config['val']}/images
      │   │
      │   │
      │   ├── names
      │   │   └── {' '.join(config['names'])}
        """
        )
        print(Fore.GREEN + "-> Success")
        print(Fore.GREEN + f"Number of classes: {len(config['names'])}"
                           f"\nClasses: {' '.join(config['names'])}"
              )

    def write_config(self, config: dict) -> None:
        with open(self.config_path, mode="w") as f:
            yaml.safe_dump(stream=f, data=config)

    def __call__(self, train_size: float,
                 classes: list[int, ...],
                 make_config: bool = True,
                 normalize: bool = True
                ) -> None:

        self.train_size = train_size
        self.classes = classes
        self.normalize = normalize

        self.__define_splitratio()
        self.__prepare_dirs()
        self.__splitfolders()
        count_dict = self.__count_dataset()
        self.__check_sanity(count_dict)
        self.__finalizing(count_dict)

        if make_config:
            config = self.get_config()
            self.write_config(config)
            self.display_config(config)

# %%
# instantiate a COCODataset object
path = '/gdrive/MyDrive/DATA/HuBMAP/'
coco = COCODataset(
    annotations_filepath= path + 'polygons.jsonl',
    images_dirpath=path + 'images/'
)
# Out:
# Processing polygons:   0%|          | 0/1633 [00:00<?, ?it/s]

# %%
coco(train_size=0.8, classes=[0, 1, 2])
# Out:
# Dataset creation:   0%|          | 0/1633 [00:00<?, ?it/s]
# ~ HuBMAP Dataset Structure ~
#
#
#           ├── dataset
#           │   │
#           │   ├── train
#           │   │   └── labels
#           │   │   └── images
#           │   │
#           │   ├── val
#           │   │   └── labels
#           │   │   └── images
#
# -> Success
# Train dataset: 1306
# Val dataset: 327
#
# ~ HuBMAP Config Structure ~
#
#
#       │   │
#       │   ├── train
#       │   │   └── /content/dataset/train/images
#       │   │
#       │   │
#       │   ├── val
#       │   │   └── /content/dataset/val/images
#       │   │
#       │   │
#       │   ├── names
#       │   │   └── blood_vessel glomerulus unsure
#
# -> Success
# Number of classes: 3
# Classes: blood_vessel glomerulus unsure

# %%
# !ls dataset
# Out:
# coco.yaml  train  val

# %%
dirlist = os.listdir("/content/dataset/val/images")
random_num = np.random.randint(0, len(dirlist))
image = Image.open("/content/dataset/val/images/"+ dirlist[random_num])
plt.imshow(image)
plt.show()

# %%
# !pip install ultralytics
display.clear_output()

# %%
pip show ultralytics
# Out:
# Name: ultralytics
# Version: 8.0.137
# Summary: Ultralytics YOLOv8 for SOTA object detection, multi-object tracking, instance segmentation, pose estimation and image classification.
# Home-page: https://github.com/ultralytics/ultralytics
# Author: Ultralytics
# Author-email: hello@ultralytics.com
# License: AGPL-3.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: matplotlib, opencv-python, pandas, Pillow, psutil, PyYAML, requests, scipy, seaborn, torch, torchvision, tqdm
# Required-by:

# %%
# !pip install pycocotools
display.clear_output()

# %%
pip show pycocotools
# Out:
# Name: pycocotools
# Version: 2.0.6
# Summary: Official APIs for the MS-COCO dataset
# Home-page: https://github.com/ppwwyyxx/cocoapi
# Author:
# Author-email:
# License: FreeBSD
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: matplotlib, numpy
# Required-by:

# %%
from pycocotools import _mask as coco_mask
import ultralytics
from ultralytics import YOLO

# %%
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.137 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (4 CPUs, 25.5 GB RAM, 26.3/166.8 GB disk)

# %%
# !nvidia-smi
# Out:
# Tue Jul 18 17:29:43 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8     9W /  70W |      3MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
def main():
    model = YOLO("yolov8x-seg.pt")
    model.train(
        # Project
        project="HuBMAP",
        name="yolov8x-seg",

        # Random Seed parameters
        deterministic=True,
        seed=43,

        # Data & model parameters
        data="/content/dataset/coco.yaml",
        save=True,
        save_period=5,
        pretrained=True,
        imgsz=512,

        # Training parameters
        epochs=60,
        batch=16,
        workers=8,
        val=True,
        device= 0,

        # Optimization parameters
        lr0=0.01,
        patience=6,
        optimizer="SGD",
        momentum=0.947,
        weight_decay=0.0005,
        close_mosaic=3,
        dropout = 0.5
    )

# %%
if __name__ == '__main__':
    main()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8x-seg.pt to yolov8x-seg.pt...
# 100%|██████████| 137M/137M [00:03<00:00, 41.0MB/s]
# Ultralytics YOLOv8.0.137 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# engine/trainer: task=segment, mode=train, model=yolov8x-seg.pt, data=/content/dataset/coco.yaml, epochs=60, patience=6, batch=16, imgsz=512, save=True, save_period=5, cache=False, device=0, workers=8, project=HuBMAP, name=yolov8x-seg, exist_ok=False, pretrained=True, optimizer=SGD, verbose=True, seed=43, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=3, resume=False, amp=True, fraction=1.0, profile=False, overlap_mask=True, mask_ratio=4, dropout=0.5, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.947, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=HuBMAP/yolov8x-seg
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100%|██████████| 755k/755k [00:00<00:00, 14.8MB/s]
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#   8                  -1  3   6969600  ultralytics.nn.modules.block.C2f             [640, 640, 3, True]
#   9                  -1  1   1025920  ultralytics.nn.modules.block.SPPF            [640, 640, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1948800  ultralytics.nn.modules.block.C2f             [960, 320, 3]
#  16                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   7174400  ultralytics.nn.modules.block.C2f             [960, 640, 3]
#  19                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  22        [15, 18, 21]  1  12319097  ultralytics.nn.modules.head.Segment          [3, 32, 320, [320, 640, 640]]
# YOLOv8x-seg summary: 401 layers, 71753737 parameters, 71753721 gradients
#
# Transferred 651/657 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir HuBMAP/yolov8x-seg', view at http://localhost:6006/
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to yolov8n.pt...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 72.6MB/s]
# AMP: checks passed ✅
# train: Scanning /content/dataset/train/labels... 1306 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1306/1306 [00:03<00:00, 431.92it/s]
# train: WARNING ⚠️ /content/dataset/train/images/005715f0a313.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/01a7fca6263b.tif: 7 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/025ec20b8b73.tif: 7 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/02cf5c2db152.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/033a656390b2.tif: 4 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/0672b96aaccc.tif: 4 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/07b809228ef4.tif: 4 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/0a631efbc3e4.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/0a993633aa5e.tif: 7 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/0ba172f33ea6.tif: 8 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/0bc3e1a729e4.tif: 7 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/0ce440ad7080.tif: 13 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/0f6e1cb07f74.tif: 8 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/0f960d864969.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/15262223b967.tif: 11 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/189064c6a137.tif: 6 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/1aeae455caeb.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/1b5da995f08e.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/1c0295c1d01d.tif: 3 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/1fc1c6cc515a.tif: 11 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/20113c729fe4.tif: 10 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/228da07bf8d9.tif: 7 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/23c30a541c7a.tif: 12 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/23c98917da69.tif: 6 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/270f0c7b0901.tif: 9 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/2ac4cfbb7405.tif: 4 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/2c369bf03bd4.tif: 7 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/314a25a7f92d.tif: 7 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/326c9663d95d.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/328a651a4ca7.tif: 12 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/329d9bc6f0f8.tif: 8 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/3398c337fe7a.tif: 8 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/340bbab914db.tif: 10 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/36be7dacbabf.tif: 11 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/38ff92c9ae72.tif: 22 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/391e9699357a.tif: 4 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/3936393ac567.tif: 2 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/3a93b29c72f2.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/3b8d1919d08e.tif: 3 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/3ca3b1b0db63.tif: 6 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/41146970649b.tif: 17 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/4142122db8e4.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/4399be208888.tif: 13 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/43ba93d8284d.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/45d42de2cb89.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/4960cdc6a274.tif: 2 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/4995f7836ec4.tif: 3 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/4a4820ef318c.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/4c058755d597.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/4e8b6849684d.tif: 10 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/501398697fc1.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/5047c7523e09.tif: 7 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/523a3912a7ee.tif: 12 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/5384b927f5b3.tif: 9 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/56102e85ff9f.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/59c99a7cd635.tif: 2 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/5c04198743a5.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/5e72a0265b2f.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/611aee20c207.tif: 11 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/68c4d1b29b13.tif: 8 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/6b1e4cea2071.tif: 7 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/6bfe9903a1cf.tif: 8 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/6d1315ab9ef7.tif: 7 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/6e74e333e5e4.tif: 5 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/6f77355f4181.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/71cd41c93924.tif: 11 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/720c0fa5ce8e.tif: 3 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/7292fe2d34d6.tif: 5 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/74e6545e7553.tif: 2 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/76e5b8a1caa1.tif: 9 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/7cb715d5413c.tif: 15 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/83a7f8ea3f09.tif: 2 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/84a3f37bf808.tif: 8 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/85affadde232.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/85f5c8b8e408.tif: 7 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/85fae4b2ca7c.tif: 2 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/861ffbc05b45.tif: 13 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/88614cbaa57c.tif: 8 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/8b29a4cb940e.tif: 6 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/8b33e8e0f0a1.tif: 15 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/8ebea8a23178.tif: 9 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/910b93e1cf28.tif: 9 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/92450a58e849.tif: 12 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/932c4fa02fee.tif: 18 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/94dd41f92b1d.tif: 6 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/99ddcf7fb9a3.tif: 4 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/9a4ac92edd79.tif: 12 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/9a4d59b6c3ec.tif: 17 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/a0fed17a5bc6.tif: 4 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/a12848a1b5f9.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/a27ffddbba42.tif: 3 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/a661cbfc8464.tif: 10 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/aa05d1efb6bc.tif: 6 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/ace43628b108.tif: 14 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/adadaeaa3635.tif: 11 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/b04db3efff0a.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/b29ab50ca7aa.tif: 6 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/b987af6e6106.tif: 2 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/ba5cffc61dce.tif: 8 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/be0d76907fd8.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/bf0f8e9bf257.tif: 9 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/bffe164b7f65.tif: 6 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/c2731b6c0c17.tif: 9 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/c3e34170ff28.tif: 7 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/c738789588f9.tif: 1 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/cc103e610139.tif: 12 duplicate labels removed
# train: WARNING ⚠️ /content/dataset/train/images/cc8bdabbc3eb.tif: 1 duplicate labels removed
# train: New cache created: /content/dataset/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/dataset/val/labels... 327 images, 0 backgrounds, 0 corrupt: 100%|██████████| 327/327 [00:01<00:00, 273.48it/s]
# val: WARNING ⚠️ /content/dataset/val/images/d0d0fda7789f.tif: 1 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/d17335683f96.tif: 4 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/d4a6a9e8d85e.tif: 8 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/d6bd77533b2b.tif: 8 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/d82695d80caf.tif: 1 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/d873758275c6.tif: 12 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/d9547a630fab.tif: 8 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/da9507215057.tif: 8 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/dbf5ec194977.tif: 7 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/dc0b64e2a3a6.tif: 12 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/e52522470fea.tif: 4 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/e9c9c5fb7aef.tif: 1 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/ef39b81a7917.tif: 1 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/f217dcd37517.tif: 10 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/f53f64d220e3.tif: 3 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/f9faf12fc07b.tif: 4 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/fa10ae8f9fec.tif: 7 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/fa6a66f01888.tif: 11 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/fbe845f13c20.tif: 8 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/fce9ad75428d.tif: 9 duplicate labels removed
# val: WARNING ⚠️ /content/dataset/val/images/ffd3d193c71e.tif: 2 duplicate labels removed
# val: New cache created: /content/dataset/val/labels.cache
# Plotting labels to HuBMAP/yolov8x-seg/labels.jpg...
# optimizer: SGD(lr=0.01, momentum=0.947) with parameter groups 106 weight(decay=0.0), 117 weight(decay=0.0005), 116 bias(decay=0.0)
# Image sizes 512 train, 512 val
# Using 4 dataloader workers
# Logging results to HuBMAP/yolov8x-seg
# Starting training for 60 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        1/60      9.87G      1.952      3.113      2.787      1.531        159        512: 100%|██████████| 82/82 [01:33<00:00,  1.14s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:10<00:00,  1.01it/s]
#                    all        327       3236      0.444      0.348      0.338      0.231      0.437      0.357      0.343      0.222
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        2/60      10.2G      1.541      2.083       1.67        1.2        155        512: 100%|██████████| 82/82 [01:23<00:00,  1.02s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:10<00:00,  1.01it/s]
#                    all        327       3236      0.475        0.5      0.478       0.34      0.474      0.508      0.485      0.335
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        3/60      10.4G      1.526      2.029      1.508      1.176        105        512: 100%|██████████| 82/82 [01:25<00:00,  1.04s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:10<00:00,  1.01it/s]
#                    all        327       3236      0.815      0.385      0.444      0.295      0.833      0.402      0.466      0.304
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        4/60      10.2G      1.552       2.04      1.472      1.202        198        512: 100%|██████████| 82/82 [01:25<00:00,  1.04s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:10<00:00,  1.00it/s]
#                    all        327       3236      0.538      0.431      0.495      0.325      0.556      0.433       0.49        0.3
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        5/60      10.3G       1.55      2.036      1.386      1.196        153        512: 100%|██████████| 82/82 [01:25<00:00,  1.05s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:11<00:00,  1.02s/it]
#                    all        327       3236      0.518      0.516      0.509      0.344      0.523      0.501      0.507       0.33
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        6/60        10G      1.558       2.01      1.361       1.19        131        512: 100%|██████████| 82/82 [01:25<00:00,  1.04s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:11<00:00,  1.00s/it]
#                    all        327       3236      0.565      0.553      0.553      0.377      0.569      0.561      0.562      0.374
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        7/60      10.3G      1.548      1.977       1.32      1.186        136        512: 100%|██████████| 82/82 [01:25<00:00,  1.05s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:11<00:00,  1.01s/it]
#                    all        327       3236      0.463      0.451      0.405      0.288      0.483      0.427      0.404      0.273
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        8/60      10.2G      1.548      1.994      1.308      1.188        147        512: 100%|██████████| 82/82 [01:25<00:00,  1.05s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:11<00:00,  1.01s/it]
#                    all        327       3236      0.597      0.445      0.493      0.336      0.607      0.454      0.503      0.339
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#        9/60        10G       1.51      1.924      1.264      1.158        142        512: 100%|██████████| 82/82 [01:26<00:00,  1.05s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:11<00:00,  1.01s/it]
#                    all        327       3236      0.807      0.427      0.499      0.334      0.814      0.429      0.504      0.333
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       10/60      10.3G      1.523      1.949      1.261      1.169        103        512: 100%|██████████| 82/82 [01:26<00:00,  1.06s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:11<00:00,  1.01s/it]
#                    all        327       3236      0.595      0.572       0.57      0.392      0.599      0.577      0.575       0.39
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       11/60      9.91G      1.492      1.892      1.226      1.157         99        512: 100%|██████████| 82/82 [01:26<00:00,  1.05s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:11<00:00,  1.01s/it]
#                    all        327       3236      0.582      0.549      0.549      0.367      0.583      0.551      0.552      0.355
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       12/60      9.88G      1.482      1.907      1.221      1.151        142        512: 100%|██████████| 82/82 [01:26<00:00,  1.05s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:10<00:00,  1.00it/s]
#                    all        327       3236      0.611      0.579      0.584      0.401      0.613      0.582       0.59      0.397
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       13/60      10.3G      1.462      1.861      1.201      1.138        160        512: 100%|██████████| 82/82 [01:26<00:00,  1.05s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:11<00:00,  1.01s/it]
#                    all        327       3236      0.561      0.487      0.536      0.349      0.562      0.488      0.533      0.342
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       14/60      10.2G      1.446      1.873      1.164      1.138        158        512: 100%|██████████| 82/82 [01:26<00:00,  1.05s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:11<00:00,  1.00s/it]
#                    all        327       3236      0.585      0.555      0.553      0.382      0.589      0.557      0.553      0.369
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       15/60      10.3G      1.448      1.846      1.154      1.129        129        512: 100%|██████████| 82/82 [01:26<00:00,  1.06s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:11<00:00,  1.01s/it]
#                    all        327       3236      0.586       0.59      0.567      0.389      0.593      0.581      0.566      0.385
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       16/60      9.85G      1.438      1.841      1.158      1.135        143        512: 100%|██████████| 82/82 [01:26<00:00,  1.05s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:11<00:00,  1.01s/it]
#                    all        327       3236      0.612       0.56      0.559      0.378      0.593      0.572      0.562       0.37
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       17/60      10.3G      1.416      1.823      1.131      1.115        112        512: 100%|██████████| 82/82 [01:26<00:00,  1.05s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:10<00:00,  1.00it/s]
#                    all        327       3236      0.556      0.568      0.557      0.381      0.563      0.575      0.561      0.369
#
#       Epoch    GPU_mem   box_loss   seg_loss   cls_loss   dfl_loss  Instances       Size
#       18/60      10.2G      1.415      1.809      1.122      1.119        184        512: 100%|██████████| 82/82 [01:25<00:00,  1.04s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:22<00:00,  2.03s/it]
#                    all        327       3236      0.563      0.584      0.572      0.394      0.565      0.585      0.571      0.385
# Stopping training early as no improvement observed in last 6 epochs. Best results observed at epoch 12, best model saved as best.pt.
# To update EarlyStopping(patience=6) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 18 epochs completed in 0.508 hours.
# Optimizer stripped from HuBMAP/yolov8x-seg/weights/last.pt, 143.9MB
# Optimizer stripped from HuBMAP/yolov8x-seg/weights/best.pt, 143.9MB
#
# Validating HuBMAP/yolov8x-seg/weights/best.pt...
# Ultralytics YOLOv8.0.137 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8x-seg summary (fused): 295 layers, 71723545 parameters, 0 gradients
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100%|██████████| 11/11 [00:21<00:00,  1.97s/it]
#                    all        327       3236      0.611      0.579      0.584      0.401      0.613      0.582       0.59      0.397
#           blood_vessel        327       2955      0.506      0.716      0.649      0.347      0.512      0.724      0.658      0.312
#             glomerulus        327        104      0.881      0.846      0.894      0.742      0.881      0.846      0.896      0.756
#                 unsure        327        177      0.446      0.175      0.211      0.115      0.446      0.175      0.215      0.122
# Speed: 0.5ms preprocess, 20.4ms inference, 0.0ms loss, 3.8ms postprocess per image
# Results saved to HuBMAP/yolov8x-seg

# %%
files.download('/content/HuBMAP/yolov8x-seg/weights/best.pt')

# %%
import matplotlib.pyplot as plt
from PIL import Image

# %%
dirlist = os.listdir("/content/dataset/val/images")
print(dirlist[:5])
# Out:
# ['dde26a95b52c.tif', 'e477bfef1e06.tif', 'd030717228ae.tif', 'f64540767eee.tif', 'e7161814d297.tif']

# %%
model = YOLO("/content/HuBMAP/yolov8x-seg/weights/best.pt")
history = model.predict("/content/dataset/val/images/fbd64e93f84d.tif")[0]
image = history.plot()
plt.imshow(image)
plt.show()
# Out:
# image 1/1 /content/dataset/val/images/fbd64e93f84d.tif: 512x512 12 blood_vessels, 69.2ms
# Speed: 1.3ms preprocess, 69.2ms inference, 8.9ms postprocess per image at shape (1, 3, 512, 512)

# %%
F1_curve = Image.open("/content/HuBMAP/yolov8x-seg/results.png")
plt.figure(figsize=(15,20))
plt.imshow(F1_curve)
plt.show()

# %%
results = pd.read_csv("/content/HuBMAP/yolov8x-seg/results.csv")
results.head()
results.to_csv('/gdrive/MyDrive/DATA/HuBMAP/Results/is_yolov8_v9_20230718.csv')

# %%
results
# Out:
#                       epoch           train/box_loss           train/seg_loss  \
# 0                         0                   1.9520                   3.1133
# 1                         1                   1.5413                   2.0832
# 2                         2                   1.5265                   2.0287
# 3                         3                   1.5521                   2.0399
# 4                         4                   1.5505                   2.0363
# 5                         5                   1.5580                   2.0097
# 6                         6                   1.5479                   1.9771
# 7                         7                   1.5484                   1.9937
# 8                         8                   1.5102                   1.9242
# 9                         9                   1.5229                   1.9489
# 10                       10                   1.4922                   1.8917
# 11                       11                   1.4823                   1.9072
# 12                       12                   1.4621                   1.8614
# 13                       13                   1.4457                   1.8727
# 14                       14                   1.4478                   1.8463
# 15                       15                   1.4381                   1.8409
# 16                       16                   1.4162                   1.8231
# 17                       17                   1.4146                   1.8090
#
#              train/cls_loss           train/dfl_loss     metrics/precision(B)  \
# 0                    2.7870                   1.5307                  0.44376
# 1                    1.6702                   1.1998                  0.47519
# 2                    1.5080                   1.1758                  0.81522
# 3                    1.4721                   1.2019                  0.53784
# 4                    1.3857                   1.1963                  0.51810
# 5                    1.3614                   1.1902                  0.56472
# 6                    1.3204                   1.1864                  0.46312
# 7                    1.3085                   1.1883                  0.59740
# 8                    1.2639                   1.1575                  0.80730
# 9                    1.2609                   1.1688                  0.59459
# 10                   1.2258                   1.1569                  0.58235
# 11                   1.2205                   1.1509                  0.61101
# 12                   1.2008                   1.1375                  0.56096
# 13                   1.1641                   1.1384                  0.58523
# 14                   1.1536                   1.1288                  0.58550
# 15                   1.1577                   1.1353                  0.61214
# 16                   1.1314                   1.1155                  0.55600
# 17                   1.1215                   1.1186                  0.56302
#
#           metrics/recall(B)         metrics/mAP50(B)      metrics/mAP50-95(B)  \
# 0                   0.34774                  0.33791                  0.23150
# 1                   0.50049                  0.47839                  0.33965
# 2                   0.38496                  0.44414                  0.29471
# 3                   0.43057                  0.49489                  0.32502
# 4                   0.51613                  0.50931                  0.34399
# 5                   0.55346                  0.55259                  0.37689
# 6                   0.45102                  0.40460                  0.28781
# 7                   0.44493                  0.49339                  0.33588
# 8                   0.42689                  0.49942                  0.33411
# 9                   0.57232                  0.56974                  0.39156
# 10                  0.54939                  0.54867                  0.36715
# 11                  0.57912                  0.58448                  0.40106
# 12                  0.48744                  0.53605                  0.34910
# 13                  0.55452                  0.55275                  0.38173
# 14                  0.59032                  0.56735                  0.38920
# 15                  0.56040                  0.55862                  0.37810
# 16                  0.56770                  0.55662                  0.38120
# 17                  0.58398                  0.57191                  0.39408
#
#        metrics/precision(M)        metrics/recall(M)         metrics/mAP50(M)  \
# 0                   0.43746                  0.35693                  0.34290
# 1                   0.47395                  0.50850                  0.48484
# 2                   0.83252                  0.40191                  0.46607
# 3                   0.55598                  0.43302                  0.48999
# 4                   0.52252                  0.50125                  0.50720
# 5                   0.56930                  0.56058                  0.56164
# 6                   0.48253                  0.42747                  0.40432
# 7                   0.60675                  0.45355                  0.50253
# 8                   0.81356                  0.42858                  0.50406
# 9                   0.59918                  0.57688                  0.57513
# 10                  0.58324                  0.55075                  0.55183
# 11                  0.61285                  0.58172                  0.58975
# 12                  0.56167                  0.48800                  0.53350
# 13                  0.58912                  0.55708                  0.55332
# 14                  0.59316                  0.58112                  0.56607
# 15                  0.59270                  0.57231                  0.56154
# 16                  0.56345                  0.57503                  0.56127
# 17                  0.56538                  0.58495                  0.57131
#
#         metrics/mAP50-95(M)             val/box_loss             val/seg_loss  \
# 0                   0.22214                   1.5559                   2.2314
# 1                   0.33456                   1.4602                   1.9764
# 2                   0.30390                   1.9018                   2.2736
# 3                   0.30041                   1.6092                   2.4246
# 4                   0.32982                   1.5601                   2.2196
# 5                   0.37374                   1.5819                   2.1900
# 6                   0.27342                   1.6090                   2.3397
# 7                   0.33888                   1.5846                   2.1078
# 8                   0.33329                   1.6448                   2.3268
# 9                   0.39030                   1.5123                   2.0220
# 10                  0.35543                   1.5361                   2.1347
# 11                  0.39653                   1.5260                   2.0710
# 12                  0.34197                   1.5872                   2.2795
# 13                  0.36874                   1.5482                   2.1237
# 14                  0.38494                   1.5049                   2.0087
# 15                  0.36958                   1.5185                   2.1258
# 16                  0.36932                   1.5058                   2.0677
# 17                  0.38539                   1.4932                   2.0899
#
#                val/cls_loss             val/dfl_loss                   lr/pg0  \
# 0                    1.7574                   1.2772                 0.070366
# 1                    1.4509                   1.1903                 0.040257
# 2                    2.2620                   1.4117                 0.010037
# 3                    2.3009                   1.2751                 0.009505
# 4                    1.6199                   1.2673                 0.009505
# 5                    1.5341                   1.2361                 0.009340
# 6                    2.2122                   1.2908                 0.009175
# 7                    1.4881                   1.2520                 0.009010
# 8                    1.4390                   1.2824                 0.008845
# 9                    1.2241                   1.2128                 0.008680
# 10                   1.3283                   1.2427                 0.008515
# 11                   1.2626                   1.2267                 0.008350
# 12                   1.3285                   1.2421                 0.008185
# 13                   1.2673                   1.2208                 0.008020
# 14                   1.2136                   1.2159                 0.007855
# 15                   1.2659                   1.2133                 0.007690
# 16                   1.2009                   1.2169                 0.007525
# 17                   1.2333                   1.2150                 0.007360
#
#                      lr/pg1                   lr/pg2
# 0                  0.003293                 0.003293
# 1                  0.006517                 0.006517
# 2                  0.009631                 0.009631
# 3                  0.009505                 0.009505
# 4                  0.009505                 0.009505
# 5                  0.009340                 0.009340
# 6                  0.009175                 0.009175
# 7                  0.009010                 0.009010
# 8                  0.008845                 0.008845
# 9                  0.008680                 0.008680
# 10                 0.008515                 0.008515
# 11                 0.008350                 0.008350
# 12                 0.008185                 0.008185
# 13                 0.008020                 0.008020
# 14                 0.007855                 0.007855
# 15                 0.007690                 0.007690
# 16                 0.007525                 0.007525
# 17                 0.007360                 0.007360

# %%
plt.figure

# %%
plt.figure(figsize=(15,20))
confusion_matrix = Image.open("/content/HuBMAP/yolov8x-seg/confusion_matrix.png")
plt.imshow(confusion_matrix)
plt.show()

# %%
plt.figure(figsize=(15,20))
confusion_matrix = Image.open("/content/HuBMAP/yolov8x-seg/confusion_matrix_normalized.png")
plt.imshow(confusion_matrix)
plt.show()

# %%
results = pd.read_csv("/gdrive/MyDrive/DATA/HuBMAP/Results/is_yolov8_v9_20230718.csv",index_col=0)
results.columns = results.columns.str.strip()

results
# Out:
#     epoch  train/box_loss  train/seg_loss  train/cls_loss  train/dfl_loss  \
# 0       0          1.9520          3.1133          2.7870          1.5307
# 1       1          1.5413          2.0832          1.6702          1.1998
# 2       2          1.5265          2.0287          1.5080          1.1758
# 3       3          1.5521          2.0399          1.4721          1.2019
# 4       4          1.5505          2.0363          1.3857          1.1963
# 5       5          1.5580          2.0097          1.3614          1.1902
# 6       6          1.5479          1.9771          1.3204          1.1864
# 7       7          1.5484          1.9937          1.3085          1.1883
# 8       8          1.5102          1.9242          1.2639          1.1575
# 9       9          1.5229          1.9489          1.2609          1.1688
# 10     10          1.4922          1.8917          1.2258          1.1569
# 11     11          1.4823          1.9072          1.2205          1.1509
# 12     12          1.4621          1.8614          1.2008          1.1375
# 13     13          1.4457          1.8727          1.1641          1.1384
# 14     14          1.4478          1.8463          1.1536          1.1288
# 15     15          1.4381          1.8409          1.1577          1.1353
# 16     16          1.4162          1.8231          1.1314          1.1155
# 17     17          1.4146          1.8090          1.1215          1.1186
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0                0.44376            0.34774           0.33791
# 1                0.47519            0.50049           0.47839
# 2                0.81522            0.38496           0.44414
# 3                0.53784            0.43057           0.49489
# 4                0.51810            0.51613           0.50931
# 5                0.56472            0.55346           0.55259
# 6                0.46312            0.45102           0.40460
# 7                0.59740            0.44493           0.49339
# 8                0.80730            0.42689           0.49942
# 9                0.59459            0.57232           0.56974
# 10               0.58235            0.54939           0.54867
# 11               0.61101            0.57912           0.58448
# 12               0.56096            0.48744           0.53605
# 13               0.58523            0.55452           0.55275
# 14               0.58550            0.59032           0.56735
# 15               0.61214            0.56040           0.55862
# 16               0.55600            0.56770           0.55662
# 17               0.56302            0.58398           0.57191
#
#     metrics/mAP50-95(B)  metrics/precision(M)  metrics/recall(M)  \
# 0               0.23150               0.43746            0.35693
# 1               0.33965               0.47395            0.50850
# 2               0.29471               0.83252            0.40191
# 3               0.32502               0.55598            0.43302
# 4               0.34399               0.52252            0.50125
# 5               0.37689               0.56930            0.56058
# 6               0.28781               0.48253            0.42747
# 7               0.33588               0.60675            0.45355
# 8               0.33411               0.81356            0.42858
# 9               0.39156               0.59918            0.57688
# 10              0.36715               0.58324            0.55075
# 11              0.40106               0.61285            0.58172
# 12              0.34910               0.56167            0.48800
# 13              0.38173               0.58912            0.55708
# 14              0.38920               0.59316            0.58112
# 15              0.37810               0.59270            0.57231
# 16              0.38120               0.56345            0.57503
# 17              0.39408               0.56538            0.58495
#
#     metrics/mAP50(M)  metrics/mAP50-95(M)  val/box_loss  val/seg_loss  \
# 0            0.34290              0.22214        1.5559        2.2314
# 1            0.48484              0.33456        1.4602        1.9764
# 2            0.46607              0.30390        1.9018        2.2736
# 3            0.48999              0.30041        1.6092        2.4246
# 4            0.50720              0.32982        1.5601        2.2196
# 5            0.56164              0.37374        1.5819        2.1900
# 6            0.40432              0.27342        1.6090        2.3397
# 7            0.50253              0.33888        1.5846        2.1078
# 8            0.50406              0.33329        1.6448        2.3268
# 9            0.57513              0.39030        1.5123        2.0220
# 10           0.55183              0.35543        1.5361        2.1347
# 11           0.58975              0.39653        1.5260        2.0710
# 12           0.53350              0.34197        1.5872        2.2795
# 13           0.55332              0.36874        1.5482        2.1237
# 14           0.56607              0.38494        1.5049        2.0087
# 15           0.56154              0.36958        1.5185        2.1258
# 16           0.56127              0.36932        1.5058        2.0677
# 17           0.57131              0.38539        1.4932        2.0899
#
#     val/cls_loss  val/dfl_loss    lr/pg0    lr/pg1    lr/pg2
# 0         1.7574        1.2772  0.070366  0.003293  0.003293
# 1         1.4509        1.1903  0.040257  0.006517  0.006517
# 2         2.2620        1.4117  0.010037  0.009631  0.009631
# 3         2.3009        1.2751  0.009505  0.009505  0.009505
# 4         1.6199        1.2673  0.009505  0.009505  0.009505
# 5         1.5341        1.2361  0.009340  0.009340  0.009340
# 6         2.2122        1.2908  0.009175  0.009175  0.009175
# 7         1.4881        1.2520  0.009010  0.009010  0.009010
# 8         1.4390        1.2824  0.008845  0.008845  0.008845
# 9         1.2241        1.2128  0.008680  0.008680  0.008680
# 10        1.3283        1.2427  0.008515  0.008515  0.008515
# 11        1.2626        1.2267  0.008350  0.008350  0.008350
# 12        1.3285        1.2421  0.008185  0.008185  0.008185
# 13        1.2673        1.2208  0.008020  0.008020  0.008020
# 14        1.2136        1.2159  0.007855  0.007855  0.007855
# 15        1.2659        1.2133  0.007690  0.007690  0.007690
# 16        1.2009        1.2169  0.007525  0.007525  0.007525
# 17        1.2333        1.2150  0.007360  0.007360  0.007360

# %%
plt.figure(figsize=(15,15))

loss_labels = results.columns.tolist()[1:5] + results.columns.tolist()[13:17]
for idx in range(4):
  plt.subplot(2,2,idx+1)
  plt.plot(results['epoch'],results[loss_labels[idx]],label = loss_labels[idx])
  plt.plot(results['epoch'],results[loss_labels[idx+4]],label = loss_labels[idx+4])
  plt.legend(loc='upper right')
  plt.xlabel('epoch')
  plt.ylabel(loss_labels[idx].split('/')[1])
  plt.title(loss_labels[idx].split('/')[1])



plt.show();

# %%
results
# Out:
#     epoch  train/box_loss  train/seg_loss  train/cls_loss  train/dfl_loss  \
# 0       0          1.8159          2.6293         2.10540          1.3595
# 1       1          1.7370          2.3230         1.65050          1.3100
# 2       2          1.7610          2.3261         1.60870          1.3168
# 3       3          1.7301          2.2734         1.55810          1.2994
# 4       4          1.7087          2.2325         1.52310          1.2779
# 5       5          1.6585          2.1672         1.47810          1.2807
# 6       6          1.6447          2.1309         1.43140          1.2511
# 7       7          1.6144          2.0895         1.40660          1.2445
# 8       8          1.5814          2.0412         1.38800          1.2277
# 9       9          1.5670          2.0216         1.33030          1.2175
# 10     10          1.5518          2.0123         1.34450          1.2166
# 11     11          1.5470          1.9719         1.30400          1.2065
# 12     12          1.5084          1.9475         1.26310          1.1880
# 13     13          1.5215          1.9453         1.27010          1.1967
# 14     14          1.4999          1.9369         1.24770          1.1811
# 15     15          1.4902          1.9056         1.22670          1.1848
# 16     16          1.4915          1.9055         1.23410          1.1806
# 17     17          1.4437          1.8657         1.20560          1.1700
# 18     18          1.4486          1.8743         1.18870          1.1522
# 19     19          1.4424          1.8493         1.18000          1.1576
# 20     20          1.4252          1.8234         1.18170          1.1442
# 21     21          1.4152          1.8167         1.15110          1.1478
# 22     22          1.4145          1.8053         1.13190          1.1429
# 23     23          1.4013          1.8141         1.13720          1.1350
# 24     24          1.3951          1.8035         1.11680          1.1304
# 25     25          1.3828          1.7945         1.12000          1.1318
# 26     26          1.3898          1.7725         1.09690          1.1355
# 27     27          1.3549          1.7595         1.08640          1.1183
# 28     28          1.3410          1.7299         1.07310          1.1045
# 29     29          1.3330          1.6995         1.05530          1.1083
# 30     30          1.3222          1.7022         1.04490          1.1070
# 31     31          1.3168          1.6939         1.03220          1.1021
# 32     32          1.3068          1.6960         1.03770          1.1048
# 33     33          1.2918          1.6879         0.99957          1.0938
# 34     34          1.2775          1.6592         0.98694          1.0869
# 35     35          1.2802          1.6623         0.98315          1.0881
# 36     36          1.2860          1.6412         0.99850          1.0814
# 37     37          1.2636          1.6346         0.95937          1.0760
# 38     38          1.2432          1.6277         0.94458          1.0600
# 39     39          1.2353          1.6352         0.93852          1.0714
# 40     40          1.2274          1.5978         0.90350          1.0575
# 41     41          1.2250          1.5897         0.90693          1.0565
# 42     42          1.1969          1.5846         0.90022          1.0497
# 43     43          1.1812          1.5476         0.88461          1.0393
# 44     44          1.1791          1.5502         0.87820          1.0384
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0                0.60456            0.25642           0.26037
# 1                0.16876            0.38561           0.16107
# 2                0.52973            0.35658           0.24308
# 3                0.63143            0.29098           0.24528
# 4                0.61223            0.42219           0.38074
# 5                0.80835            0.36380           0.45545
# 6                0.46178            0.52032           0.48339
# 7                0.53762            0.52673           0.52840
# 8                0.56763            0.54032           0.55067
# 9                0.43887            0.58536           0.53325
# 10               0.64345            0.50746           0.54799
# 11               0.59588            0.52754           0.54279
# 12               0.57758            0.54313           0.55179
# 13               0.55796            0.53984           0.54435
# 14               0.54864            0.56442           0.55589
# 15               0.61233            0.53303           0.56755
# 16               0.56377            0.58424           0.57436
# 17               0.58599            0.53180           0.55556
# 18               0.54720            0.59718           0.58732
# 19               0.63790            0.52178           0.57452
# 20               0.54288            0.59243           0.57850
# 21               0.57772            0.57182           0.57353
# 22               0.54000            0.60251           0.57455
# 23               0.59300            0.58444           0.58686
# 24               0.52666            0.61872           0.57833
# 25               0.60328            0.55566           0.57093
# 26               0.55771            0.61227           0.59424
# 27               0.57201            0.59892           0.59719
# 28               0.60805            0.56469           0.58296
# 29               0.57639            0.59567           0.59350
# 30               0.60445            0.58854           0.60407
# 31               0.57874            0.59242           0.60560
# 32               0.57351            0.61660           0.59495
# 33               0.59572            0.62339           0.59933
# 34               0.64609            0.57740           0.59226
# 35               0.62801            0.57456           0.59819
# 36               0.59770            0.61551           0.59831
# 37               0.60264            0.61925           0.61622
# 38               0.60772            0.60091           0.60743
# 39               0.58480            0.64294           0.60414
# 40               0.57868            0.63307           0.59897
# 41               0.61507            0.61235           0.60339
# 42               0.58700            0.62935           0.60250
# 43               0.59217            0.61395           0.60876
# 44               0.59424            0.62349           0.60933
#
#     metrics/mAP50-95(B)  metrics/precision(M)  metrics/recall(M)  \
# 0               0.14071               0.58929            0.24929
# 1               0.07361               0.17157            0.38352
# 2               0.13074               0.53535            0.35347
# 3               0.13107               0.63238            0.29206
# 4               0.22577               0.62069            0.42466
# 5               0.27447               0.81221            0.36658
# 6               0.28886               0.45248            0.52226
# 7               0.34044               0.53894            0.52827
# 8               0.35456               0.56234            0.52467
# 9               0.32952               0.45343            0.58783
# 10              0.35379               0.58792            0.53061
# 11              0.34205               0.59679            0.52792
# 12              0.35449               0.58614            0.55248
# 13              0.35701               0.55918            0.53645
# 14              0.37145               0.55402            0.56821
# 15              0.37509               0.60181            0.52456
# 16              0.38572               0.56354            0.58394
# 17              0.36127               0.59542            0.53803
# 18              0.38095               0.54487            0.60035
# 19              0.38642               0.63885            0.52255
# 20              0.39162               0.54818            0.59916
# 21              0.38264               0.58074            0.58220
# 22              0.38897               0.54401            0.60618
# 23              0.40094               0.59356            0.58506
# 24              0.39164               0.51347            0.62761
# 25              0.38304               0.61592            0.55511
# 26              0.41031               0.56191            0.61823
# 27              0.41116               0.57491            0.60031
# 28              0.40354               0.61037            0.56701
# 29              0.41109               0.57495            0.62144
# 30              0.41443               0.59590            0.58130
# 31              0.40882               0.57784            0.58967
# 32              0.40711               0.57708            0.62077
# 33              0.41685               0.60006            0.61366
# 34              0.41040               0.59985            0.60377
# 35              0.41218               0.63309            0.57171
# 36              0.42535               0.60360            0.61866
# 37              0.42514               0.60549            0.61544
# 38              0.42651               0.61497            0.59664
# 39              0.42216               0.59034            0.63360
# 40              0.41334               0.57920            0.63232
# 41              0.42405               0.61791            0.61326
# 42              0.42532               0.60447            0.58845
# 43              0.42703               0.59971            0.59781
# 44              0.42615               0.59326            0.62068
#
#     metrics/mAP50(M)  metrics/mAP50-95(M)  val/box_loss  val/seg_loss  \
# 0            0.25190              0.12150        1.9306        3.0187
# 1            0.16730              0.06723        1.8362        3.3366
# 2            0.24600              0.12310        1.8841        3.1828
# 3            0.24104              0.12657        1.7890        2.8224
# 4            0.38686              0.22525        1.6593        2.4008
# 5            0.45804              0.27122        1.6963        2.5469
# 6            0.48446              0.27860        1.6825        2.3337
# 7            0.52775              0.33306        1.6103        2.2730
# 8            0.54963              0.33089        1.5730        2.1801
# 9            0.53418              0.33350        1.5532        2.1480
# 10           0.55097              0.35074        1.5497        2.1875
# 11           0.54733              0.33517        1.5805        2.1870
# 12           0.56182              0.35712        1.5586        2.1652
# 13           0.54181              0.34400        1.5529        2.2319
# 14           0.55634              0.36006        1.5720        2.2045
# 15           0.55837              0.36385        1.5439        2.1425
# 16           0.57224              0.36784        1.5002        2.0302
# 17           0.55657              0.35510        1.5330        2.0620
# 18           0.58859              0.37939        1.5044        2.0339
# 19           0.57611              0.37600        1.4713        1.9926
# 20           0.57823              0.38120        1.5056        2.0588
# 21           0.56781              0.36101        1.5561        2.2118
# 22           0.57670              0.37539        1.5018        2.1950
# 23           0.59004              0.39643        1.4899        2.0654
# 24           0.58049              0.38086        1.5113        2.1252
# 25           0.57293              0.35916        1.5303        2.1509
# 26           0.59789              0.39584        1.4603        1.9355
# 27           0.60245              0.40097        1.4710        1.9882
# 28           0.58401              0.38696        1.4762        2.0042
# 29           0.60205              0.40420        1.4942        2.0582
# 30           0.59673              0.38805        1.4869        2.1015
# 31           0.60168              0.39230        1.5104        2.0221
# 32           0.59722              0.38953        1.4915        2.0841
# 33           0.59790              0.41554        1.4879        2.0102
# 34           0.59513              0.39523        1.4772        2.0101
# 35           0.59379              0.39087        1.4802        1.9751
# 36           0.60079              0.40796        1.4641        2.0214
# 37           0.61003              0.39770        1.5265        2.1830
# 38           0.60163              0.40662        1.4825        2.0680
# 39           0.59942              0.39407        1.5053        2.1195
# 40           0.59444              0.39080        1.5116        2.1862
# 41           0.60091              0.40067        1.4903        2.1013
# 42           0.59668              0.40144        1.4814        2.0139
# 43           0.60190              0.40160        1.4851        2.0490
# 44           0.60549              0.40295        1.4992        2.1070
#
#     val/cls_loss  val/dfl_loss    lr/pg0    lr/pg1    lr/pg2
# 0         2.4357        1.5422  0.067379  0.000329  0.000329
# 1         5.2986        1.5227  0.034366  0.000650  0.000650
# 2         2.8907        1.4907  0.001339  0.000956  0.000956
# 3         2.4410        1.4144  0.000940  0.000940  0.000940
# 4         1.8259        1.3889  0.000940  0.000940  0.000940
# 5         2.0235        1.3501  0.000920  0.000920  0.000920
# 6         1.5192        1.3527  0.000900  0.000900  0.000900
# 7         1.3819        1.3075  0.000880  0.000880  0.000880
# 8         1.3613        1.2897  0.000860  0.000860  0.000860
# 9         1.3778        1.2750  0.000840  0.000840  0.000840
# 10        1.3267        1.2733  0.000820  0.000820  0.000820
# 11        1.3195        1.2791  0.000800  0.000800  0.000800
# 12        1.2586        1.2720  0.000780  0.000780  0.000780
# 13        1.2970        1.2596  0.000760  0.000760  0.000760
# 14        1.2558        1.2750  0.000740  0.000740  0.000740
# 15        1.2590        1.2580  0.000720  0.000720  0.000720
# 16        1.2534        1.2498  0.000700  0.000700  0.000700
# 17        1.2371        1.2655  0.000680  0.000680  0.000680
# 18        1.2195        1.2417  0.000660  0.000660  0.000660
# 19        1.1928        1.2232  0.000640  0.000640  0.000640
# 20        1.2156        1.2396  0.000620  0.000620  0.000620
# 21        1.2397        1.2554  0.000600  0.000600  0.000600
# 22        1.1920        1.2474  0.000580  0.000580  0.000580
# 23        1.1999        1.2362  0.000560  0.000560  0.000560
# 24        1.2030        1.2496  0.000540  0.000540  0.000540
# 25        1.1915        1.2511  0.000520  0.000520  0.000520
# 26        1.1480        1.2240  0.000500  0.000500  0.000500
# 27        1.1483        1.2350  0.000480  0.000480  0.000480
# 28        1.1567        1.2321  0.000460  0.000460  0.000460
# 29        1.1510        1.2328  0.000440  0.000440  0.000440
# 30        1.1474        1.2409  0.000420  0.000420  0.000420
# 31        1.1405        1.2444  0.000400  0.000400  0.000400
# 32        1.1500        1.2363  0.000380  0.000380  0.000380
# 33        1.1282        1.2280  0.000360  0.000360  0.000360
# 34        1.1352        1.2387  0.000340  0.000340  0.000340
# 35        1.1248        1.2343  0.000320  0.000320  0.000320
# 36        1.1076        1.2323  0.000300  0.000300  0.000300
# 37        1.1133        1.2491  0.000280  0.000280  0.000280
# 38        1.1239        1.2410  0.000260  0.000260  0.000260
# 39        1.1062        1.2477  0.000240  0.000240  0.000240
# 40        1.1091        1.2443  0.000220  0.000220  0.000220
# 41        1.1144        1.2520  0.000200  0.000200  0.000200
# 42        1.1082        1.2406  0.000180  0.000180  0.000180
# 43        1.1174        1.2425  0.000160  0.000160  0.000160
# 44        1.1119        1.2438  0.000140  0.000140  0.000140
